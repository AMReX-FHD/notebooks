# %%
import yt
import numpy as np
import math
import matplotlib.pyplot as plt
# Out:
# /usr/lib/python3.8/_collections_abc.py:666: MatplotlibDeprecationWarning: The global colormaps dictionary is no longer considered public API.
#   self[key]

# %%
def return_y_dens_cplt(folder,time,nbins,field="densityMean"):
    ds = yt.load(folder+'/cplt'+time+'/')
    ad = ds.all_data()
    plot = yt.ProfilePlot(ad,"y",[field],weight_field="cell_volume",x_log=False,y_log={field:False},n_bins=nbins)
    profile = plot.profiles[0]
    x = np.array(profile.x)
    y = np.array(profile[field])
    return x, y

def return_y_plt(folder,time,nbins,field="densityMean"):
    ds = yt.load(folder+'/plt'+time+'/')
    ad = ds.all_data()
    plot = yt.ProfilePlot(ad,"y",[field],weight_field="cell_volume",x_log=False,y_log={field:False},n_bins=nbins)
    profile = plot.profiles[0]
    x = np.array(profile.x)
    y = np.array(profile[field])
    return x, y

# %%
time = "{:09d}".format(int(480000))
#time = "{:09d}".format(int(220000))
x1a, y1a = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_50wet1',time,nbins=48,field="chargeDensityMeanSpecies00000")
x1b, y1b = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_50wet2',time,nbins=48,field="chargeDensityMeanSpecies00000")
x1c, y1c = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_50wet3',time,nbins=48,field="chargeDensityMeanSpecies00000")
x1d, y1d = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_50wet4',time,nbins=48,field="chargeDensityMeanSpecies00000")
x1e, y1e = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_50wet5',time,nbins=48,field="chargeDensityMeanSpecies00000")
x1f, y1f = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_50wet6',time,nbins=48,field="chargeDensityMeanSpecies00000")
time = "{:09d}".format(int(400000))
x1g, y1g = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_50wet7',time,nbins=48,field="chargeDensityMeanSpecies00000")
x1h, y1h = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_50wet8',time,nbins=48,field="chargeDensityMeanSpecies00000")
x1i, y1i = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_50wet9',time,nbins=48,field="chargeDensityMeanSpecies00000")
x1j, y1j = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_50wet10',time,nbins=48,field="chargeDensityMeanSpecies00000")
# Out:
# yt : [INFO     ] 2022-01-17 18:48:06,990 Parameters: current_time              = 2.3995111109309694e-08
# yt : [INFO     ] 2022-01-17 18:48:06,992 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2022-01-17 18:48:06,993 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-17 18:48:06,994 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2022-01-17 18:48:12,957 Parameters: current_time              = 2.3995111109309694e-08
# yt : [INFO     ] 2022-01-17 18:48:12,958 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2022-01-17 18:48:12,959 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-17 18:48:12,961 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2022-01-17 18:48:19,801 Parameters: current_time              = 2.3995111109309694e-08
# ...

# %%
#time = "{:09d}".format(int(60000))
time = "{:09d}".format(int(240000))
x7a, y7a = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet1',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7b, y7b = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet2',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7c, y7c = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet3',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7d, y7d = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet4',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7e, y7e = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet5',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7f, y7f = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet6',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7g, y7g = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet7',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7h, y7h = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet8',time,nbins=48,field="chargeDensityMeanSpecies00000")
time = "{:09d}".format(int(180000))
x7i, y7i = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet9',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7j, y7j = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet10',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7k, y7k = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet11',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7l, y7l = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet12',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7m, y7m = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet13',time,nbins=48,field="chargeDensityMeanSpecies00000")
x7n, y7n = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/1_1_100wet14',time,nbins=48,field="chargeDensityMeanSpecies00000")
# Out:
# yt : [INFO     ] 2022-01-17 18:49:10,627 Parameters: current_time              = 2.399022221890981e-08
# yt : [INFO     ] 2022-01-17 18:49:10,629 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2022-01-17 18:49:10,632 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-17 18:49:10,633 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2022-01-17 18:49:19,038 Parameters: current_time              = 2.399022221890981e-08
# yt : [INFO     ] 2022-01-17 18:49:19,039 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2022-01-17 18:49:19,041 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-17 18:49:19,042 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2022-01-17 18:49:27,173 Parameters: current_time              = 2.399022221890981e-08
# ...

# %%
time = "{:09d}".format(int(580000))
x10a, y10a = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/2_1_50wet1',time,nbins=48,field="chargeDensityMeanSpecies00000")
x10b, y10b = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/2_1_50wet1',time,nbins=48,field="chargeDensityMeanSpecies00000")
x10c, y10c = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/2_1_50wet3',time,nbins=48,field="chargeDensityMeanSpecies00000")
x10d, y10d = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/2_1_50wet4',time,nbins=48,field="chargeDensityMeanSpecies00000")
x10e, y10e = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/2_1_50wet5',time,nbins=48,field="chargeDensityMeanSpecies00000")
x10f, y10f = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/2_1_50wet6',time,nbins=48,field="chargeDensityMeanSpecies00000")
time = "{:09d}".format(int(490000))
x10g, y10g = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/2_1_50wet7',time,nbins=48,field="chargeDensityMeanSpecies00000")
x10h, y10h = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/2_1_50wet8',time,nbins=48,field="chargeDensityMeanSpecies00000")
x10i, y10i = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/2_1_50wet9',time,nbins=48,field="chargeDensityMeanSpecies00000")
x10j, y10j = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp3/2_1_50wet10',time,nbins=48,field="chargeDensityMeanSpecies00000")
# Out:
# yt : [INFO     ] 2022-01-17 18:51:01,316 Parameters: current_time              = 5.799022221849838e-08
# yt : [INFO     ] 2022-01-17 18:51:01,317 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2022-01-17 18:51:01,318 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-17 18:51:01,320 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2022-01-17 18:51:07,196 Parameters: current_time              = 5.799022221849838e-08
# yt : [INFO     ] 2022-01-17 18:51:07,197 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2022-01-17 18:51:07,199 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-17 18:51:07,200 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2022-01-17 18:51:09,204 Parameters: current_time              = 5.799022221849838e-08
# ...

# %%
y1=[]
x1=x1b
rat = 30/38
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10) in zip(y1a,y1b,y1c,y1d,y1e,y1f,y1g,y1h,y1i,y1j):
    y1.append((item1+item2+item3+item4+item5+item6+rat*item7+rat*item8+rat*item9+rat*item10)/(6+4*rat))

              
y7=[]
x7=x7b
rat=8/14
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14) in zip(y7a,y7b,y7c,y7d,y7e,y7f,y7g,y7h,y7i,y7j,y7k,y7l,y7m,y7n):
    y7.append((item1+item2+item3+item4+item5+item6+item7+item8+rat*item9+rat*item10+rat*item11+rat*item12+rat*item13+rat*item14)/(8+6*rat))
    
y10=[]
x10=x10a
rat = 39/48
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10) in zip(y10a,y10b,y10c,y10d,y10e,y10f,y10g,y10h,y10i,y10j):
    y10.append((item1+item2+item3+item4+item5+item6+rat*item7+rat*item8+rat*item9+rat*item10)/(6+4*rat))

# %%
time = "{:09d}".format(int(900000))
#time = "{:09d}".format(int(220000))
x11a, y11a = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp8/1_1_50wet1',time,nbins=48,field="chargeDensityMeanSpecies00000")
x11b, y11b = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp8/1_1_50wet2',time,nbins=48,field="chargeDensityMeanSpecies00000")
x11c, y11c = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp8/1_1_50wet3',time,nbins=48,field="chargeDensityMeanSpecies00000")
x11d, y11d = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp8/1_1_50wet4',time,nbins=48,field="chargeDensityMeanSpecies00000")
x11e, y11e = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp8/1_1_50wet5',time,nbins=48,field="chargeDensityMeanSpecies00000")
# Out:
# yt : [INFO     ] 2022-01-17 18:53:00,055 Parameters: current_time              = 4.4995111110060946e-08
# yt : [INFO     ] 2022-01-17 18:53:00,057 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2022-01-17 18:53:00,058 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-17 18:53:00,060 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2022-01-17 18:53:06,355 Parameters: current_time              = 4.4995111110060946e-08
# yt : [INFO     ] 2022-01-17 18:53:06,356 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2022-01-17 18:53:06,357 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-17 18:53:06,358 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2022-01-17 18:53:12,562 Parameters: current_time              = 4.4995111110060946e-08
# ...

# %%
y11=[]
x11=x11b
for (item1,item2,item3,item4,item5) in zip(y11a,y11b,y11c,y11d,y11e):
    y11.append((item1+item2+item3+item4+item5)/(5))

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)
#ax1.scatter(x1,y1,s=150,color='black',facecolors='none',marker='o', linewidths=2, label='100\% wet')
#ax1.scatter(x2,y2,s=150,color='red',marker='x', linewidths=3, label='50\% wet')
#ax1.scatter(x3,y3,s=150,color='green',marker='s',facecolors='none', linewidths=3, label='50\% wet')
#ax1.plot(xa,ya,color='black', linewidth=2, label='50\% wet')
#ax1.plot(xd,yd, color='hotpink', linestyle='dashed',linewidth=3.5, label='50\% wet - no dry')
ax1.plot(x1,y1,color='red', linestyle='dashed',linewidth=3.5, label='wet drift off')
ax1.plot(x2,y2,color='green', linestyle='dashed',linewidth=3.5, label='dry drift off')
ax1.plot(x3,y3,color='orange', linestyle='dashed',linewidth=3.5, label='rfd off')
#ax1.plot(x4,y4,color='purple', linestyle='dashed',linewidth=3.5, label='midpoint off')
#ax1.plot(x4,y4,color='blue', linestyle='dashdot',linewidth=3.5, label='6nm fit')
ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$\varrho\,(\mathrm{C}/\mathrm{cm}^3)$", fontsize=30,rotation=90, labelpad=10)
ax1.set_ylim([-5,155])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.65,0.04),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)

ax2 = fig.add_subplot(1,2,2)
#ax2.plot(xa,ya,color='green', linewidth=2, label='50\% wet')
#ax2.scatter(x1,y1,s=150,color='black',facecolors='none',marker='o', linewidths=2, label='100\% wet')
#ax2.scatter(x2,y2,s=150,color='red',marker='x', linewidths=3, label='50\% wet')
#ax2.scatter(x3,y3,s=150,color='green',marker='s',facecolors='none', linewidths=3, label='50\% wet')
#ax2.plot(xb,yb,color='blue', linewidth=2, label='100\% wet')
#ax2.plot(x6,y6,color='black', linewidth=2, label='100\% wet no dry move')
ax2.plot(x9,y9,color='green',linewidth=2, label='100\% wet wet drift off')
#ax2.plot(x1,y1,color='orange', linestyle='dashed',linewidth=3.5, label='50\% wet wet drift off')
#ax2.plot(x2,y2,color='blue', linestyle='dashed',linewidth=3.5, label='50\% wet dry drift off')
#ax2.plot(x5,y5,color='purple', linestyle='dashed',linewidth=3.5, label='50\% wet no dry move')
#ax2.plot(x11,y11,color='green', linestyle='dashed',linewidth=3.5, label='50\% wet no wet move')
ax2.plot(x12,y12,color='blue',linewidth=2, label='50\% wet no dry move no wet drift')
ax2.plot(x13,y13,color='orange',linewidth=2, label='50\% wet no wet move')
#ax2.plot(xc,yc,color='orange', linestyle='dashdot',linewidth=3.5, label='100% wet, half timestep')
ax2.set_xlabel(r'$y$', fontsize=30)
ax2.set_ylabel(r"$\varrho\,(\mathrm{C}/\mathrm{cm}^3)$", fontsize=30,rotation=90, labelpad=10)
ax2.set_ylim([-5,155])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.65,0.04),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

# ax2 = fig.add_subplot(1,2,2)
# ax2.scatter(xpos,nmob,s=150,color='black',facecolors='none',marker='o', linewidths=2, label='100\% wet')
# ax2.scatter(xpos,nmob50,s=150,color='red',marker='x', linewidths=3, label='50\% wet')
# ax2.set_xlabel(r'$\tilde{y}/a_t$', fontsize=30)
# ax2.set_ylabel(r'$\gamma_{\bot}$', fontsize=30,rotation=0, labelpad=15)
# ax2.set_ylim([0.005,1.05])
# ax2.tick_params(labelsize=20)
# ax2.legend(loc=(0.65,0.04),fontsize=20)
# ax2.xaxis.set_tick_params(width=1.5)
# ax2.yaxis.set_tick_params(width=1.5)
# fig.savefig("mob3.pdf", bbox_inches = 'tight',
#     pad_inches = 0.05)

# %%
xC=np.linspace(0.5*0.0625e-7,3e-7-0.5*0.0625e-7,48)
xR=xC[::-1]
print(xC)
print(xR)
# Out:
# [3.12500e-09 9.37500e-09 1.56250e-08 2.18750e-08 2.81250e-08 3.43750e-08
#  4.06250e-08 4.68750e-08 5.31250e-08 5.93750e-08 6.56250e-08 7.18750e-08
#  7.81250e-08 8.43750e-08 9.06250e-08 9.68750e-08 1.03125e-07 1.09375e-07
#  1.15625e-07 1.21875e-07 1.28125e-07 1.34375e-07 1.40625e-07 1.46875e-07
#  1.53125e-07 1.59375e-07 1.65625e-07 1.71875e-07 1.78125e-07 1.84375e-07
#  1.90625e-07 1.96875e-07 2.03125e-07 2.09375e-07 2.15625e-07 2.21875e-07
#  2.28125e-07 2.34375e-07 2.40625e-07 2.46875e-07 2.53125e-07 2.59375e-07
#  2.65625e-07 2.71875e-07 2.78125e-07 2.84375e-07 2.90625e-07 2.96875e-07]
# [2.96875e-07 2.90625e-07 2.84375e-07 2.78125e-07 2.71875e-07 2.65625e-07
#  2.59375e-07 2.53125e-07 2.46875e-07 2.40625e-07 2.34375e-07 2.28125e-07
#  2.21875e-07 2.15625e-07 2.09375e-07 2.03125e-07 1.96875e-07 1.90625e-07
#  1.84375e-07 1.78125e-07 1.71875e-07 1.65625e-07 1.59375e-07 1.53125e-07
#  1.46875e-07 1.40625e-07 1.34375e-07 1.28125e-07 1.21875e-07 1.15625e-07
# ...

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

yd=np.zeros(len(x10))
ax1.plot(xC,y1,color='black', linewidth=2.0, label='50\% wet')
#ax1.plot(xC,y11,color='blue', linewidth=2.0, label='50\% wet')
#ax1.plot(xC,y11,color='blue', linewidth=2.0, label='50\% wet')
#ax1.plot(x2,y2,color='blue',linewidth=2, label='50\% wet, wet part only')
#ax1.plot(x4,y4,color='red',linewidth=2, label='50\% wet, dry part only')
ax1.plot(xC,y7,color='red', linestyle='dashed',linewidth=3.5, label='100\% wet')
ax1.plot(xR,y11,color='blue', linestyle='dashed',linewidth=3.5, label='100\% wet')
#ax1.plot(xC,y12,color='blue', linestyle='dashed',linewidth=3.5, label='100\% wet')
ax1.plot(xC,yd,color='black',linewidth=2, label='from Ref.')
#ax1.plot([6*0.0625e-7-0.03125e-7,6*0.0625e-7-0.03125e-7],[100,140],color='black',linewidth=1, label='_not in legend')
#ax1.plot([7*0.0625e-7-0.03125e-7,7*0.0625e-7-0.03125e-7],[100,140],color='black',linewidth=1, label='_not in legend')


ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$n_+$", fontsize=30,rotation=0, labelpad=15)
ax1.set_ylim([-5,155])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.05,0.78),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


ax2 = fig.add_subplot(1,2,2)
ax2.plot(xC,y10,color='black',linewidth=2, label='50\% wet')
#ax2.plot(xC,y110,color='blue',linewidth=2, label='50\% wet')
ax2.plot(xC,yd,color='black',linewidth=2, label='from Ref.')


ax2.set_xlabel(r'$y$', fontsize=30)
ax2.set_ylabel(r"$n_+$", fontsize=30, labelpad=15,rotation=0)
ax2.set_ylim([-5,155])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.05,0.83),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("static1_raw.svg", bbox_inches = 'tight', pad_inches = 0.05)

# %%
time = "{:09d}".format(int(830000))
#time = "{:09d}".format(int(220000))
x11a, y11a = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100dry1',time,nbins=48,field="chargeDensityMeanSpecies00000")
x11b, y11b = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100dry2',time,nbins=48,field="chargeDensityMeanSpecies00000")
# Out:
# yt : [INFO     ] 2021-11-09 15:05:03,572 Parameters: current_time              = 8.299022221974338e-08
# yt : [INFO     ] 2021-11-09 15:05:03,573 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2021-11-09 15:05:03,574 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-09 15:05:03,575 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2021-11-09 15:05:24,614 Parameters: current_time              = 8.299022221974338e-08
# yt : [INFO     ] 2021-11-09 15:05:24,615 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2021-11-09 15:05:24,616 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-09 15:05:24,617 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]

# %%
#time = "{:09d}".format(int(60000))
time = "{:09d}".format(int(240000))
x17a, y17a = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet1',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17b, y17b = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet2',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17c, y17c = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet3',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17d, y17d = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet4',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17e, y17e = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet5',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17f, y17f = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet6',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17g, y17g = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet7',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17h, y17h = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet8',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17i, y17i = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet9',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17j, y17j = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet10',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17k, y17k = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet11',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17l, y17l = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet12',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17m, y17m = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet13',time,nbins=48,field="chargeDensityMeanSpecies00000")
x17n, y17n = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp5/1_1_100wet14',time,nbins=48,field="chargeDensityMeanSpecies00000")

#x7i, y7i = return_y_dens_cplt('~/coriProject/dladiges/static_eq_tests/100wet_nodrymove9',time,nbins=48,field="chargeDensityMeanSpecies00000")
#x7j, y7j = return_y_dens_cplt('~/coriProject/dladiges/static_eq_tests/100wet_nodrymove10',time,nbins=48,field="chargeDensityMeanSpecies00000")
# Out:
# yt : [INFO     ] 2021-11-09 14:58:24,038 Parameters: current_time              = 2.399022221890981e-08
# yt : [INFO     ] 2021-11-09 14:58:24,040 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2021-11-09 14:58:24,041 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-09 14:58:24,042 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2021-11-09 14:58:52,999 Parameters: current_time              = 2.399022221890981e-08
# yt : [INFO     ] 2021-11-09 14:58:53,001 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2021-11-09 14:58:53,002 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-09 14:58:53,003 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2021-11-09 14:59:24,259 Parameters: current_time              = 2.399022221890981e-08
# ...

# %%
time = "{:09d}".format(int(560000))
x110a, y110a = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp4/2_1_50wet1',time,nbins=48,field="chargeDensityMeanSpecies00000")
x110b, y110b = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp4/2_1_50wet1',time,nbins=48,field="chargeDensityMeanSpecies00000")
x110c, y110c = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp4/2_1_50wet3',time,nbins=48,field="chargeDensityMeanSpecies00000")
x110d, y110d = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp4/2_1_50wet4',time,nbins=48,field="chargeDensityMeanSpecies00000")
x110e, y110e = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp4/2_1_50wet5',time,nbins=48,field="chargeDensityMeanSpecies00000")
x110f, y110f = return_y_dens_cplt('~/coriProject/dladiges/static_eq_comp4/2_1_50wet6',time,nbins=48,field="chargeDensityMeanSpecies00000")
# Out:
# yt : [INFO     ] 2021-10-25 13:56:03,796 Parameters: current_time              = 5.599022221852258e-08
# yt : [INFO     ] 2021-10-25 13:56:03,797 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2021-10-25 13:56:03,798 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-10-25 13:56:03,799 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2021-10-25 13:56:27,303 Parameters: current_time              = 5.599022221852258e-08
# yt : [INFO     ] 2021-10-25 13:56:27,304 Parameters: domain_dimensions         = [192  48 192]
# yt : [INFO     ] 2021-10-25 13:56:27,305 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-10-25 13:56:27,306 Parameters: domain_right_edge         = [1.2e-06 3.0e-07 1.2e-06]
# yt : [INFO     ] 2021-10-25 13:56:29,303 Parameters: current_time              = 5.599022221852258e-08
# ...

# %%
y11=[]
x11=x11b
for (item1,item2) in zip(y11a,y11b):
    y11.append((item1+item2)/2)
      
y17=[]
x17=x17b
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14) in zip(y17a,y17b,y17c,y17d,y17e,y17f,y17g,y17h,y17i,y17j,y17k,y17l,y17m,y17n):
    y17.append((item1+item2+item3+item4+item5+item6+item7+item8+item9+item10+item11+item12+item13+item14)/14)

# %%
xCr = xC[::-1]

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

#yd=np.zeros(len(x10))
ax1.plot(xCr,y1,color='black', linewidth=2.0, label='100\% wet')
#ax1.plot(xC,y11,color='blue', linewidth=2.0, label='50\% wet')
#ax1.plot(xC,y11,color='blue', linewidth=2.0, label='50\% wet')
#ax1.plot(x2,y2,color='blue',linewidth=2, label='50\% wet, wet part only')
#ax1.plot(x4,y4,color='red',linewidth=2, label='50\% wet, dry part only')
ax1.plot(xCr,y11,color='red', linewidth=2.0, label='100\% dry, no drift correction')
ax1.plot(xCr,y17,color='blue', linestyle='dashed',linewidth=3.5, label='100\% wet, no drift correction')
#ax1.plot(xC,y12,color='blue', linestyle='dashed',linewidth=3.5, label='100\% wet')
#ax1.plot(xC,yd,color='black',linewidth=2, label='from Ref.')
#ax1.plot([6*0.0625e-7-0.03125e-7,6*0.0625e-7-0.03125e-7],[100,140],color='black',linewidth=1, label='_not in legend')
#ax1.plot([7*0.0625e-7-0.03125e-7,7*0.0625e-7-0.03125e-7],[100,140],color='black',linewidth=1, label='_not in legend')


ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$n_+$", fontsize=30,rotation=0, labelpad=15)
ax1.set_ylim([-5,165])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.4,0.78),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


#ax2 = fig.add_subplot(1,2,2)
#ax2.plot(xC,y10,color='black',linewidth=2, label='50\% wet')
#ax2.plot(xC,y110,color='blue',linewidth=2, label='50\% wet')
#ax2.plot(xC,yd,color='black',linewidth=2, label='from Ref.')


#ax2.set_xlabel(r'$y$', fontsize=30)
#ax2.set_ylabel(r"$n_+$", fontsize=30, labelpad=15,rotation=0)
#ax2.set_ylim([-5,155])
#ax2.tick_params(labelsize=20)
#ax2.legend(loc=(0.05,0.83),fontsize=20)
#ax2.xaxis.set_tick_params(width=1.5)
#ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("static2.svg", bbox_inches = 'tight', pad_inches = 0.05)
# Out:
# No handles with labels found to put in legend.

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

#yd=np.zeros(len(x10))
ax1.plot([1,2],[1,2],color='black', linewidth=2.0, label='Correct solution, \nincluding drift correction')
#ax1.plot(xC,y11,color='blue', linewidth=2.0, label='50\% wet')
#ax1.plot(xC,y11,color='blue', linewidth=2.0, label='50\% wet')
#ax1.plot(x2,y2,color='blue',linewidth=2, label='50\% wet, wet part only')
#ax1.plot(x4,y4,color='red',linewidth=2, label='50\% wet, dry part only')
ax1.plot([1,2],[1,2],color='red', linewidth=2.0, label='100\% dry, no drift correction')
ax1.plot([1,2],[1,2],color='blue', linestyle='dashed',linewidth=3.5, label='100\% wet, no drift correction')
#ax1.plot(xC,y12,color='blue', linestyle='dashed',linewidth=3.5, label='100\% wet')
#ax1.plot(xC,yd,color='black',linewidth=2, label='from Ref.')
#ax1.plot([6*0.0625e-7-0.03125e-7,6*0.0625e-7-0.03125e-7],[100,140],color='black',linewidth=1, label='_not in legend')
#ax1.plot([7*0.0625e-7-0.03125e-7,7*0.0625e-7-0.03125e-7],[100,140],color='black',linewidth=1, label='_not in legend')


ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$n_+$", fontsize=30,rotation=0, labelpad=15)
ax1.set_ylim([-5,165])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.2,0.78),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


#ax2 = fig.add_subplot(1,2,2)
#ax2.plot(xC,y10,color='black',linewidth=2, label='50\% wet')
#ax2.plot(xC,y110,color='blue',linewidth=2, label='50\% wet')
#ax2.plot(xC,yd,color='black',linewidth=2, label='from Ref.')


#ax2.set_xlabel(r'$y$', fontsize=30)
#ax2.set_ylabel(r"$n_+$", fontsize=30, labelpad=15,rotation=0)
#ax2.set_ylim([-5,155])
#ax2.tick_params(labelsize=20)
#ax2.legend(loc=(0.05,0.83),fontsize=20)
#ax2.xaxis.set_tick_params(width=1.5)
#ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("staticL.svg", bbox_inches = 'tight', pad_inches = 0.05)

# %%
time = "{:010d}".format(int(170000))
print(time)
# Out:
# 0000170000

# %%
time = "{:09d}".format(int(300000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/low',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 18:30:06,531 Parameters: current_time              = 1.491904503285931e-08
# yt : [INFO     ] 2022-04-26 18:30:06,532 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2022-04-26 18:30:06,534 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 18:30:06,535 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 18:30:13,396 Parameters: current_time              = 1.491904503285931e-08
# yt : [INFO     ] 2022-04-26 18:30:13,397 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2022-04-26 18:30:13,399 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 18:30:13,400 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 18:30:17,026 Parameters: current_time              = 1.491904503285931e-08
# ...

# %%
time = "{:08d}".format(int(50000))
X1b, Y1b = return_y_plt('~/Downloads/case1test',time,nbins=256,field="rho1")
X2b, Y2b = return_y_plt('~/Downloads/case1test',time,nbins=256,field="rho2")
X3b,Y3b = return_y_plt('~/Downloads/case1test',time,nbins=256,field="averaged_velx")

time = "{:08d}".format(int(5000))
X1b2, Y1b2 = return_y_plt('~/Downloads/case1',time,nbins=64,field="rho1")
X2b2, Y2b2 = return_y_plt('~/Downloads/case1',time,nbins=64,field="rho2")
X3b2,Y3b2 = return_y_plt('~/Downloads/case1',time,nbins=64,field="averaged_velx")

time = "{:08d}".format(int(200000))
X1b3, Y1b3 = return_y_plt('~/Downloads/case1test2',time,nbins=512,field="rho1")
X2b3, Y2b3 = return_y_plt('~/Downloads/case1test2',time,nbins=512,field="rho2")
X3b3,Y3b3 = return_y_plt('~/Downloads/case1test2',time,nbins=512,field="averaged_velx")
# Out:
# yt : [INFO     ] 2022-04-26 18:30:20,818 Parameters: current_time              = 4.999999999996013e-10
# yt : [INFO     ] 2022-04-26 18:30:20,818 Parameters: domain_dimensions         = [ 32 256   1]
# yt : [INFO     ] 2022-04-26 18:30:20,819 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 18:30:20,819 Parameters: domain_right_edge         = [7.5e-08 6.0e-07 1.0e+00]
# yt : [INFO     ] 2022-04-26 18:30:20,972 Parameters: current_time              = 4.999999999996013e-10
# yt : [INFO     ] 2022-04-26 18:30:20,973 Parameters: domain_dimensions         = [ 32 256   1]
# yt : [INFO     ] 2022-04-26 18:30:20,973 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 18:30:20,973 Parameters: domain_right_edge         = [7.5e-08 6.0e-07 1.0e+00]
# yt : [INFO     ] 2022-04-26 18:30:21,138 Parameters: current_time              = 4.999999999996013e-10
# ...

# %%
time = "{:09d}".format(int(110000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low_rev/',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low_rev/',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/low_rev/',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2021-11-09 13:58:20,641 Parameters: current_time              = 5.4190450329406595e-09
# yt : [INFO     ] 2021-11-09 13:58:20,643 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2021-11-09 13:58:20,644 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-09 13:58:20,645 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-09 13:59:29,317 Parameters: current_time              = 5.4190450329406595e-09
# yt : [INFO     ] 2021-11-09 13:59:29,318 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2021-11-09 13:59:29,320 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-09 13:59:29,322 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-09 14:00:26,742 Parameters: current_time              = 5.4190450329406595e-09
# ...

# %%
time = "{:09d}".format(int(120000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests5/case4',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests5/case4',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests5/case4',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2021-11-09 14:16:58,385 Parameters: current_time              = 5.919045032942881e-09
# yt : [INFO     ] 2021-11-09 14:16:58,387 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2021-11-09 14:16:58,388 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-09 14:16:58,389 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-09 14:18:06,291 Parameters: current_time              = 5.919045032942881e-09
# yt : [INFO     ] 2021-11-09 14:18:06,292 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2021-11-09 14:18:06,294 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-09 14:18:06,295 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-09 14:19:06,529 Parameters: current_time              = 5.919045032942881e-09
# ...

# %%
time = "{:09d}".format(int(120000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests5/case10',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests5/case10',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests5/case10',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2021-11-09 14:19:16,914 Parameters: current_time              = 5.919045032942881e-09
# yt : [INFO     ] 2021-11-09 14:19:16,916 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2021-11-09 14:19:16,917 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-09 14:19:16,918 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-09 14:20:28,499 Parameters: current_time              = 5.919045032942881e-09
# yt : [INFO     ] 2021-11-09 14:20:28,500 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2021-11-09 14:20:28,501 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-09 14:20:28,502 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-09 14:21:28,265 Parameters: current_time              = 5.919045032942881e-09
# ...

# %%
def mirrorAv(arr):
    l = len(arr);
    out=[]
    for i in range(l):
        out.append((arr[i]+arr[l-1-i])/2);
    return out

# %%
Y3b
# Out:
# array([ 476.65165671, 1165.7148434 , 1595.27895608, 1866.14065734,
#        2037.77143754, 2146.7818052 , 2216.12084668, 2260.28628109,
#        2288.46778028, 2306.49889154, 2318.08480351, 2325.57908706,
#        2330.47640995, 2333.72548257, 2335.92794949, 2337.46483451,
#        2338.57694102, 2339.41597901, 2340.0770792 , 2340.61947174,
#        2341.07963918, 2341.47968433, 2341.83265547, 2342.14593702,
#        2342.42340976, 2342.66682861, 2342.87670213, 2343.05285476,
#        2343.1947862 , 2343.30190086, 2343.373653  , 2343.40963651,
#        2343.40963654, 2343.37365308, 2343.30190098, 2343.19478638,
#        2343.05285498, 2342.8767024 , 2342.66682892, 2342.42341013,
#        2342.14593743, 2341.83265592, 2341.47968482, 2341.07963972,
#        2340.61947232, 2340.07707981, 2339.41597965, 2338.5769417 ,
#        2337.46483523, 2335.92795024, 2333.72548335, 2330.47641076,
#        2325.57908788, 2318.08480435, 2306.49889239, 2288.46778112,
# ...

# %%
kb=1.38064852e-16
T=300
eps= 586.66e-21
q=1.6e-19
n0=(Y1a[56])-(Y2a[56])
ld=(q*n0/(eps*kb*T))**(-0.5)
eta=0.4e-2
sigma=3.030337469743975e13*eps
E=5.5e13

LL=40
xT=np.linspace(0,6e-7,LL)
YT=[]
for i in range(LL):
    if i<LL/2:
        val=((sigma*ld*E)/eta)*(1-math.exp(-xT[i]/ld))
        YT.append(val)
    else:
        val=((sigma*ld*E)/eta)*(1-math.exp(-(6e-7-xT[i])/ld))
        YT.append(val)

print(YT)
# Out:
# [0.0, 2736.19392978133, 4131.084008056533, 4842.187965014035, 5204.703152035712, 5389.510534325691, 5483.723879784324, 5531.753100005518, 5556.238017549061, 5568.720235339671, 5575.083571491206, 5578.327550057893, 5579.981304737909, 5580.82437582653, 5581.254166816121, 5581.473270871791, 5581.584968390756, 5581.64191090469, 5581.670939749047, 5581.685738424878, 5581.685738424878, 5581.670939749047, 5581.64191090469, 5581.584968390756, 5581.473270871791, 5581.254166816121, 5580.82437582653, 5579.981304737909, 5578.327550057893, 5575.083571491206, 5568.720235339671, 5556.238017549061, 5531.753100005518, 5483.723879784324, 5389.51053432569, 5204.703152035712, 4842.1879650140345, 4131.0840080565295, 2736.19392978132, 0.0]

# %%
ld=(q*n0/(eps*kb*T))**(-0.5)
lgc=2*kb*T*eps/(q*sigma)

print(ld/6e-7)
print(lgc/6e-7)
# Out:
# 0.03805705310006752
# 0.02847555209990868

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(X1a,mirrorAv(Y1a),color='red',linewidth=2, label='DISCOS cation')
ax1.plot(X2a,mirrorAv(-Y2a),color='blue',linewidth=2, label='DISCOS anion')
#ax1.plot(X1b,mirrorAv(q*Y1b/3.82e-23),color='red',linestyle='dotted',linewidth=2, label='Continuum cation')
#ax1.plot(X1b2,mirrorAv(q*Y1b2/3.82e-23),color='red',linestyle='dotted',linewidth=2, label='Continuum cation')
ax1.plot(X1b3,mirrorAv(q*Y1b3/3.82e-23),color='red',linestyle='dotted',linewidth=2, label='PNP cation')
ax1.plot(X2b3,mirrorAv(q*Y2b3/5.89e-23),color='blue',linestyle='dotted',linewidth=2, label='PNP anion')
ax1.plot(X1a,mirrorAv(Y1a/10),color='red',linewidth=2,linestyle='dashed', label='MD cation')
ax1.plot(X2a,mirrorAv(-Y2a/10),color='blue',linewidth=2,linestyle='dashed', label='MD anion')
#ax1.plot(X2b,mirrorAv(Y1b+Y2b),color='black',linestyle='dashed',linewidth=2, label='charge')

ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$\varrho$", fontsize=30,rotation=0, labelpad=15)
ax1.set_ylim([-20,1444])
ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.58,0.61),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


ax2 = fig.add_subplot(1,2,2)
ax2.plot(X3a,mirrorAv(Y3a),color='black',linewidth=2, label='DISCOS')
#ax2.plot(X3b,Y3b,color='black',linestyle='dotted',linewidth=2, label='Continuum')
#ax2.plot(X3b2,Y3b2,color='black',linestyle='dotted',linewidth=2, label='Continuum')
ax2.plot(X3b3,Y3b3,color='black',linestyle='dotted',linewidth=2, label='Continuum')
#ax2.plot(X3b,Y3b,color='black',linestyle='dashed',linewidth=2, label='MD')
ax2.plot(xT,YT,color='black',linestyle='dashdot',linewidth=2, label='Theory')

ax2.set_xlabel(r'$y$', fontsize=30)
ax2.set_ylabel(r"$v_x$", fontsize=30, labelpad=15,rotation=0)
ax2.set_ylim([-100,6400])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.55,0.05),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("EO_rawB.svg", bbox_inches = 'tight', pad_inches = 0.05)

# %%
Y3b[128]/Y3b3[256]
# Out:
# 1.0019624967549536

# %%
time = "{:09d}".format(int(240000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low_50',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low_50',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/low_50',time,nbins=28,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2021-11-11 17:09:13,625 Parameters: current_time              = 5.959522516447806e-09
# yt : [INFO     ] 2021-11-11 17:09:13,626 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2021-11-11 17:09:13,627 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-11 17:09:13,628 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-11 17:09:15,740 Parameters: current_time              = 5.959522516447806e-09
# yt : [INFO     ] 2021-11-11 17:09:15,741 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2021-11-11 17:09:15,742 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-11 17:09:15,744 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-11 17:09:17,373 Parameters: current_time              = 5.959522516447806e-09
# ...

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(X1a,mirrorAv(Y1a),color='red',linewidth=2, label='DISCOS cation')
ax1.plot(X2a,mirrorAv(-Y2a),color='blue',linewidth=2, label='DISCOS anion')
ax1.plot(X1c,mirrorAv(Y1c),color='red',linewidth=2,linestyle='dashed', label='DISCOS cation')
ax1.plot(X2c,mirrorAv(-Y2c),color='blue',linewidth=2,linestyle='dashed', label='DISCOS anion')

#ax1.plot(X2b,mirrorAv(Y1b+Y2b),color='black',linestyle='dashed',linewidth=2, label='charge')

ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$\varrho$", fontsize=30,rotation=0, labelpad=15)
ax1.set_ylim([-20,1444])
ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.6),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


ax2 = fig.add_subplot(1,2,2)
ax2.plot(X3a,mirrorAv(Y3a),color='black',linewidth=2, label='DISCOS')
ax2.plot(X3c,mirrorAv(Y3c),color='black',linewidth=2,linestyle='dashed', label='DISCOS')


ax2.set_xlabel(r'$y$', fontsize=30)
ax2.set_ylabel(r"$v_x$", fontsize=30, labelpad=15,rotation=0)
ax2.set_ylim([-100,6400])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.55,0.05),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("EO_raw.svg", bbox_inches = 'tight', pad_inches = 0.05)

# %%
time = "{:09d}".format(int(170000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low2/',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low2/',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/low2/',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2021-11-14 15:57:15,307 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2021-11-14 15:57:15,308 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2021-11-14 15:57:15,308 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-14 15:57:15,309 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-14 15:58:45,801 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2021-11-14 15:58:45,802 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2021-11-14 15:58:45,803 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-14 15:58:45,803 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-14 16:00:01,628 Parameters: current_time              = 8.419045032937965e-09
# ...

# %%
kb=1.38064852e-16
T=300
eps= 586.66e-21
q=1.6e-19
n0=(Y1b[28])-(Y2b[28])
ld=(q*n0/(eps*kb*T))**(-0.5)
eta=0.4e-2
sigma=8.333428050318755e12*eps
E=5.5e13

LL=40
xT=np.linspace(0,6e-7,LL)
YT=[]
for i in range(LL):
    if i<LL/2:
        val=((sigma*ld*E)/eta)*(1-math.exp(-xT[i]/ld))
        YT.append(val)
    else:
        val=((sigma*ld*E)/eta)*(1-math.exp(-(6e-7-xT[i])/ld))
        YT.append(val)

print(YT)
# Out:
# [0.0, 741.0180975660321, 1105.9437673403274, 1285.65698203459, 1374.1594969596745, 1417.7439109460927, 1439.2077206937306, 1449.7779013327627, 1454.9833480850132, 1457.546849771111, 1458.8092852943992, 1459.4309909320832, 1459.7371593603302, 1459.8879366748233, 1459.9621892641446, 1459.9987560848194, 1460.016763973655, 1460.0256322333053, 1460.029999543096, 1460.0321502914458, 1460.0321502914458, 1460.029999543096, 1460.0256322333053, 1460.016763973655, 1459.9987560848194, 1459.9621892641446, 1459.8879366748233, 1459.7371593603302, 1459.4309909320832, 1458.8092852943992, 1457.546849771111, 1454.9833480850132, 1449.7779013327627, 1439.2077206937306, 1417.7439109460927, 1374.1594969596742, 1285.6569820345896, 1105.9437673403265, 741.0180975660293, 0.0]

# %%
time = "{:08d}".format(int(5000))
X1c, Y1c = return_y_plt('~/Downloads/case2',time,nbins=32,field="rho1")
X2c, Y2c = return_y_plt('~/Downloads/case2',time,nbins=32,field="rho2")
X3c,Y3c = return_y_plt('~/Downloads/case2',time,nbins=32,field="averaged_velx")
# Out:
# yt : [INFO     ] 2021-11-14 16:08:28,127 Parameters: current_time              = 4.999999999999697e-10
# yt : [INFO     ] 2021-11-14 16:08:28,128 Parameters: domain_dimensions         = [ 8 64  1]
# yt : [INFO     ] 2021-11-14 16:08:28,130 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-14 16:08:28,131 Parameters: domain_right_edge         = [7.5e-08 6.0e-07 1.0e+00]
# yt : [INFO     ] 2021-11-14 16:08:28,299 Parameters: current_time              = 4.999999999999697e-10
# yt : [INFO     ] 2021-11-14 16:08:28,299 Parameters: domain_dimensions         = [ 8 64  1]
# yt : [INFO     ] 2021-11-14 16:08:28,300 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-14 16:08:28,300 Parameters: domain_right_edge         = [7.5e-08 6.0e-07 1.0e+00]
# yt : [INFO     ] 2021-11-14 16:08:28,447 Parameters: current_time              = 4.999999999999697e-10
# ...

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(X1b,mirrorAv(Y1b),color='red',linewidth=2, label='DISCOS cation')
ax1.plot(X2b,mirrorAv(-Y2b),color='blue',linewidth=2, label='DISCOS anion')
ax1.plot(X1c,mirrorAv(q*Y1c/3.82e-23),color='red',linestyle='dotted',linewidth=2, label='Continuum cation')
ax1.plot(X2c,mirrorAv(q*Y2c/5.89e-23),color='blue',linestyle='dotted',linewidth=2, label='Continuum anion')


ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$\varrho$", fontsize=30,rotation=0, labelpad=15)
ax1.set_ylim([-10,410])
ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.72),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)

Xm=[0.5e-7,1.5e-7]
Ym=[3000,3000]

ax2 = fig.add_subplot(1,2,2)
ax2.plot(X3b,mirrorAv(Y3b),color='black',linewidth=2, label='DISCOS')
ax2.plot(X3c,Y3c,color='black',linestyle='dotted',linewidth=2, label='Continuum')
ax2.plot(Xm,Ym,color='black',linestyle='dashed',linewidth=2, label='MD max vel')
ax2.plot(xT,YT,color='black',linestyle='dashdot',linewidth=2, label='Theory')

ax2.set_xlabel(r'$y$', fontsize=30)
ax2.set_ylabel(r"$v_x$", fontsize=30, labelpad=15,rotation=0)
ax2.set_ylim([-100,3200])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.6,0.73),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("EO2_raw.svg", bbox_inches = 'tight', pad_inches = 0.05)

# %%
time = "{:09d}".format(int(300000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/low',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2021-11-18 11:46:32,297 Parameters: current_time              = 1.491904503285931e-08
# yt : [INFO     ] 2021-11-18 11:46:32,298 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2021-11-18 11:46:32,300 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-18 11:46:32,301 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-18 11:46:35,191 Parameters: current_time              = 1.491904503285931e-08
# yt : [INFO     ] 2021-11-18 11:46:35,192 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2021-11-18 11:46:35,193 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-18 11:46:35,195 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-18 11:46:37,363 Parameters: current_time              = 1.491904503285931e-08
# ...

# %%
time = "{:09d}".format(int(340000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low_85',time,nbins=96,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low_85',time,nbins=96,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/low_85',time,nbins=48,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2021-11-18 11:46:40,125 Parameters: current_time              = 1.691904503283511e-08
# yt : [INFO     ] 2021-11-18 11:46:40,127 Parameters: domain_dimensions         = [96 96 96]
# yt : [INFO     ] 2021-11-18 11:46:40,128 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-18 11:46:40,129 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-18 11:46:43,052 Parameters: current_time              = 1.691904503283511e-08
# yt : [INFO     ] 2021-11-18 11:46:43,053 Parameters: domain_dimensions         = [96 96 96]
# yt : [INFO     ] 2021-11-18 11:46:43,054 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-18 11:46:43,056 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-18 11:46:44,993 Parameters: current_time              = 1.691904503283511e-08
# yt : [INFO     ] 2021-11-18 11:46:44,994 Parameters: domain_dimensions         = [48 48 48]
# ...

# %%
time = "{:09d}".format(int(250000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low_50',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low_50',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/low_50',time,nbins=28,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2021-11-18 11:41:34,070 Parameters: current_time              = 6.2095225164447806e-09
# yt : [INFO     ] 2021-11-18 11:41:34,072 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2021-11-18 11:41:34,073 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-18 11:41:34,074 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-18 11:41:49,659 Parameters: current_time              = 6.2095225164447806e-09
# yt : [INFO     ] 2021-11-18 11:41:49,661 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2021-11-18 11:41:49,662 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-11-18 11:41:49,663 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2021-11-18 11:41:58,982 Parameters: current_time              = 6.2095225164447806e-09
# ...

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

#ax1.plot(X1a,mirrorAv(Y1a),color='red',linewidth=2, label='100%')
ax1.plot(X2a,mirrorAv(-Y2a),color='blue',linewidth=2, label='100%')
#ax1.plot(X1b,mirrorAv(Y1b),color='red',linewidth=2,linestyle='dashed', label='85%')
ax1.plot(X2b,mirrorAv(-Y2b),color='blue',linewidth=2,linestyle='dashed', label='85%')
#ax1.plot(X1c,mirrorAv(Y1c),color='red',linewidth=2,linestyle='dotted', label='50%')
ax1.plot(X2c,mirrorAv(-Y2c),color='blue',linewidth=2,linestyle='dotted', label='50%')


ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$\varrho$", fontsize=30,rotation=0, labelpad=15)
ax1.set_ylim([-10,1510])
ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.72),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)

Xm=[0.5e-7,1.5e-7]
Ym=[3000,3000]

ax2 = fig.add_subplot(1,2,2)
ax2.plot(X3a,mirrorAv(Y3a),color='black',linewidth=2, label='100%')
ax2.plot(X3b,mirrorAv(Y3b),color='black',linewidth=2,linestyle='dashed', label='85%')
ax2.plot(X3c,mirrorAv(Y3c),color='black',linewidth=2,linestyle='dotted', label='50%')

ax2.set_xlabel(r'$y$', fontsize=30)
ax2.set_ylabel(r"$v_x$", fontsize=30, labelpad=15,rotation=0)
ax2.set_ylim([-100,5200])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.6,0.73),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("EO4_raw.svg", bbox_inches = 'tight', pad_inches = 0.05)

# %%
time = "{:09d}".format(int(180000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/low4',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(150000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4b',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4b',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/low4b',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(160000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4c',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4c',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/low4c',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4d',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4d',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/low4d',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4e',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4e',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/low4e',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4f',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4f',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/low4f',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4g',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4g',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/low4g',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4h',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4h',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/low4h',time,nbins=56,field="averaged_meanx")


time = "{:09d}".format(int(180000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4i',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4i',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/low4i',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4j',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4j',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/low4j',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4k',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4k',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/low4k',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4l',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4l',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/low4l',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4m',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4m',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/low4m',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4n',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4n',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/low4n',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4o',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4o',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/low4o',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4p',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4p',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/low4p',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-03-21 10:34:42,432 Parameters: current_time              = 8.919045032931915e-09
# yt : [INFO     ] 2022-03-21 10:34:42,433 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-03-21 10:34:42,434 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-03-21 10:34:42,436 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-03-21 10:34:57,656 Parameters: current_time              = 8.919045032931915e-09
# yt : [INFO     ] 2022-03-21 10:34:57,657 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-03-21 10:34:57,658 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-03-21 10:34:57,658 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-03-21 10:35:09,411 Parameters: current_time              = 8.919045032931915e-09
# ...

# %%
yC100=[]
yA100=[]
yV100=[]
xC100=X1b
xA100=X1b
xV100=X3b
ratb = 5/8
ratc = 6/8
ratd = 1
rate = 1
ratf = 1
ratg = 7/8
rath = 7/8
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yC100.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yA100.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yV100.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVel100=[]
midVel100.append((Y3a[28]+Y3a[27])/2)
midVel100.append((Y3b[28]+Y3b[27])/2)
midVel100.append((Y3c[28]+Y3c[27])/2)
midVel100.append((Y3d[28]+Y3d[27])/2)
midVel100.append((Y3e[28]+Y3e[27])/2)
midVel100.append((Y3f[28]+Y3f[27])/2)
midVel100.append((Y3g[28]+Y3g[27])/2)
midVel100.append((Y3h[28]+Y3h[27])/2)
midVel100.append((Y3i[28]+Y3i[27])/2)
midVel100.append((Y3j[28]+Y3j[27])/2)
midVel100.append((Y3k[28]+Y3k[27])/2)
midVel100.append((Y3l[28]+Y3l[27])/2)
midVel100.append((Y3m[28]+Y3m[27])/2)
midVel100.append((Y3n[28]+Y3n[27])/2)
midVel100.append((Y3o[28]+Y3o[27])/2)
midVel100.append((Y3p[28]+Y3p[27])/2)

# %%
stderror100=np.std(midVel100)/np.sqrt(32)
errorLine100X = [(xV100[28]+xV100[27])/2,(xV100[28]+xV100[27])/2]
errorLine100Y = [(yV100[28]+yV100[27])/2-stderror100,(yV100[28]+yV100[27])/2+stderror100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-be03984b5960> in <module>
# ----> 1 stderror100=np.std(midVel100)/np.sqrt(32)
#       2 errorLine100X = [(xV100[28]+xV100[27])/2,(xV100[28]+xV100[27])/2]
#       3 errorLine100Y = [(yV100[28]+yV100[27])/2-stderror100,(yV100[28]+yV100[27])/2+stderror100]
#
# NameError: name 'midVel100' is not defined

# %%
time = "{:09d}".format(int(290000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85b',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85b',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85b',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85c',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85c',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85c',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85d',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85d',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85d',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85e',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85e',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85e',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85f',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85f',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85f',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85g',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85g',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85g',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85h',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85h',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85h',time,nbins=48,field="averaged_meanx")


time = "{:09d}".format(int(290000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85i',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85i',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85i',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85j',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85j',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85j',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85k',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85k',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85k',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85l',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85l',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85l',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85m',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85m',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85m',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85n',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85n',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85n',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85o',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85o',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85o',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=48,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 19:29:17,784 Parameters: current_time              = 1.4419045032865359e-08
# yt : [INFO     ] 2022-04-26 19:29:17,785 Parameters: domain_dimensions         = [192 192 192]
# yt : [INFO     ] 2022-04-26 19:29:17,785 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 19:29:17,786 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 19:29:21,429 Parameters: current_time              = 1.4419045032865359e-08
# yt : [INFO     ] 2022-04-26 19:29:21,431 Parameters: domain_dimensions         = [192 192 192]
# yt : [INFO     ] 2022-04-26 19:29:21,432 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 19:29:21,433 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 19:29:24,456 Parameters: current_time              = 1.4419045032865359e-08
# ...

# %%
yC85a=[]
yA85a=[]
yV85a=[]
xC85=X1b
xA85=X1b
xV85=X3b
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yC85a.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yA85a.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yV85a.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVel85=[]
midVel85.append((Y3a[24]+Y3a[23])/2)
midVel85.append((Y3b[24]+Y3b[23])/2)
midVel85.append((Y3c[24]+Y3c[23])/2)
midVel85.append((Y3d[24]+Y3d[23])/2)
midVel85.append((Y3e[24]+Y3e[23])/2)
midVel85.append((Y3f[24]+Y3f[23])/2)
midVel85.append((Y3g[24]+Y3g[23])/2)
midVel85.append((Y3h[24]+Y3h[23])/2)
midVel85.append((Y3i[24]+Y3i[23])/2)
midVel85.append((Y3j[24]+Y3j[23])/2)
midVel85.append((Y3k[24]+Y3k[23])/2)
midVel85.append((Y3l[24]+Y3l[23])/2)
midVel85.append((Y3m[24]+Y3m[23])/2)
midVel85.append((Y3n[24]+Y3n[23])/2)
midVel85.append((Y3o[24]+Y3o[23])/2)
midVel85.append((Y3p[24]+Y3p[23])/2)

# %%
time = "{:09d}".format(int(300000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85b',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85b',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85b',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85c',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85c',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85c',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85d',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85d',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85d',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85e',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85e',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85e',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85f',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85f',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85f',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85g',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85g',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85g',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85h',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85h',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85h',time,nbins=48,field="averaged_meanx")


time = "{:09d}".format(int(300000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85i',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85i',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85i',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85j',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85j',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85j',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85k',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85k',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85k',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85l',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85l',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85l',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85m',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85m',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85m',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85n',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85n',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85n',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85o',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85o',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3/low4_nowall_85o',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=48,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 19:31:29,419 Parameters: current_time              = 1.491904503285931e-08
# yt : [INFO     ] 2022-04-26 19:31:29,421 Parameters: domain_dimensions         = [192 192 192]
# yt : [INFO     ] 2022-04-26 19:31:29,421 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 19:31:29,422 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 19:31:33,220 Parameters: current_time              = 1.491904503285931e-08
# yt : [INFO     ] 2022-04-26 19:31:33,221 Parameters: domain_dimensions         = [192 192 192]
# yt : [INFO     ] 2022-04-26 19:31:33,223 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 19:31:33,224 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 19:31:36,167 Parameters: current_time              = 1.491904503285931e-08
# ...

# %%
yC85b=[]
yA85b=[]
yV85b=[]
xC85=X1b
xA85=X1b
xV85=X3b
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yC85b.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yA85b.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yV85b.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVel85.append((Y3a[24]+Y3a[23])/2)
midVel85.append((Y3b[24]+Y3b[23])/2)
midVel85.append((Y3c[24]+Y3c[23])/2)
midVel85.append((Y3d[24]+Y3d[23])/2)
midVel85.append((Y3e[24]+Y3e[23])/2)
midVel85.append((Y3f[24]+Y3f[23])/2)
midVel85.append((Y3g[24]+Y3g[23])/2)
midVel85.append((Y3h[24]+Y3h[23])/2)
midVel85.append((Y3i[24]+Y3i[23])/2)
midVel85.append((Y3j[24]+Y3j[23])/2)
midVel85.append((Y3k[24]+Y3k[23])/2)
midVel85.append((Y3l[24]+Y3l[23])/2)
midVel85.append((Y3m[24]+Y3m[23])/2)
midVel85.append((Y3n[24]+Y3n[23])/2)
midVel85.append((Y3o[24]+Y3o[23])/2)
midVel85.append((Y3p[24]+Y3p[23])/2)

# %%
time = "{:09d}".format(int(200000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(240000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85b',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85b',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85b',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(260000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85c',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85c',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85c',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85d',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85d',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85d',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(190000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85e',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85e',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85e',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(260000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85f',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85f',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85f',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(260000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85g',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85g',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85g',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(260000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85h',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85h',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85h',time,nbins=48,field="averaged_meanx")


time = "{:09d}".format(int(250000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85i',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85i',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85i',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(260000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85j',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85j',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85j',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(190000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85k',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85k',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85k',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(260000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85l',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85l',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85l',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(260000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85m',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85m',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85m',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(260000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85n',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85n',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85n',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(200000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85o',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85o',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3b/low4_nowall_85o',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(200000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=48,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 19:33:42,505 Parameters: current_time              = 9.919045032919814e-09
# yt : [INFO     ] 2022-04-26 19:33:42,506 Parameters: domain_dimensions         = [192 192 192]
# yt : [INFO     ] 2022-04-26 19:33:42,508 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 19:33:42,509 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 19:33:56,738 Parameters: current_time              = 9.919045032919814e-09
# yt : [INFO     ] 2022-04-26 19:33:56,739 Parameters: domain_dimensions         = [192 192 192]
# yt : [INFO     ] 2022-04-26 19:33:56,740 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 19:33:56,741 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 19:34:05,571 Parameters: current_time              = 9.919045032919814e-09
# ...

# %%
yC85c=[]
yA85c=[]
yV85c=[]
xC85c=X1b
xA85c=X1b
xV85c=X3b
ratb = 14/10
ratc = 16/10
ratd = 15/10
rate = 9/10
ratf = 16/10
ratg = 16/10
rath = 16/10
rati = 15/10
ratj = 16/10
ratk = 9/10
ratl = 16/10
ratm = 16/10
ratn = 16/10
rato = 10/10
ratp = 10/10

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yC85c.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yA85c.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yV85c.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVel85.append((Y3a[24]+Y3a[23])/2)
midVel85.append((Y3b[24]+Y3b[23])/2)
midVel85.append((Y3c[24]+Y3c[23])/2)
midVel85.append((Y3d[24]+Y3d[23])/2)
midVel85.append((Y3e[24]+Y3e[23])/2)
midVel85.append((Y3f[24]+Y3f[23])/2)
midVel85.append((Y3g[24]+Y3g[23])/2)
midVel85.append((Y3h[24]+Y3h[23])/2)
midVel85.append((Y3i[24]+Y3i[23])/2)
midVel85.append((Y3j[24]+Y3j[23])/2)
midVel85.append((Y3k[24]+Y3k[23])/2)
midVel85.append((Y3l[24]+Y3l[23])/2)
midVel85.append((Y3m[24]+Y3m[23])/2)
midVel85.append((Y3n[24]+Y3n[23])/2)
midVel85.append((Y3o[24]+Y3o[23])/2)
midVel85.append((Y3p[24]+Y3p[23])/2)

# %%
time = "{:09d}".format(int(250000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85b',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85b',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85b',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85c',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85c',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85c',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85d',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85d',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85d',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85e',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85e',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85e',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85f',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85f',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85f',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85g',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85g',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85g',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85h',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85h',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85h',time,nbins=48,field="averaged_meanx")


time = "{:09d}".format(int(250000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85i',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85i',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85i',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85j',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85j',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85j',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85k',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85k',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85k',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85l',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85l',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85l',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85m',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85m',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85m',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85n',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85n',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85n',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85o',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85o',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall3c/low4_nowall_85o',time,nbins=48,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=192,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=192,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_85p',time,nbins=48,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 19:40:18,301 Parameters: current_time              = 1.2419045032889561e-08
# yt : [INFO     ] 2022-04-26 19:40:18,303 Parameters: domain_dimensions         = [192 192 192]
# yt : [INFO     ] 2022-04-26 19:40:18,304 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 19:40:18,305 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 19:40:32,552 Parameters: current_time              = 1.2419045032889561e-08
# yt : [INFO     ] 2022-04-26 19:40:32,553 Parameters: domain_dimensions         = [192 192 192]
# yt : [INFO     ] 2022-04-26 19:40:32,554 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 19:40:32,556 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 19:40:40,615 Parameters: current_time              = 1.2419045032889561e-08
# ...

# %%
yC85d=[]
yA85d=[]
yV85d=[]
xC85d=X1b
xA85d=X1b
xV85d=X3b
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yC85d.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yA85d.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yV85d.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVel85.append((Y3a[24]+Y3a[23])/2)
midVel85.append((Y3b[24]+Y3b[23])/2)
midVel85.append((Y3c[24]+Y3c[23])/2)
midVel85.append((Y3d[24]+Y3d[23])/2)
midVel85.append((Y3e[24]+Y3e[23])/2)
midVel85.append((Y3f[24]+Y3f[23])/2)
midVel85.append((Y3g[24]+Y3g[23])/2)
midVel85.append((Y3h[24]+Y3h[23])/2)
midVel85.append((Y3i[24]+Y3i[23])/2)
midVel85.append((Y3j[24]+Y3j[23])/2)
midVel85.append((Y3k[24]+Y3k[23])/2)
midVel85.append((Y3l[24]+Y3l[23])/2)
midVel85.append((Y3m[24]+Y3m[23])/2)
midVel85.append((Y3n[24]+Y3n[23])/2)
midVel85.append((Y3o[24]+Y3o[23])/2)
midVel85.append((Y3p[24]+Y3p[23])/2)

# %%
yC85=[]
yA85=[]
yV85=[]
xC85=X1b
xA85=X1b
xV85=X3b

ratb=1
ratc=21/32
ratd=24/32

for (item1,item2,item3,item4) in zip(yC85a,yC85b,yC85c,yC85d):
    yC85.append((item1+ratb*item2+ratc*item3+ratd*item4)/(1+ratb+ratc+ratd))

for (item1,item2,item3,item4) in zip(yA85a,yA85b,yA85c,yA85d):
    yA85.append((item1+ratb*item2+ratc*item3+ratd*item4)/(1+ratb+ratc+ratd))
    
for (item1,item2,item3,item4) in zip(yV85a,yV85b,yV85c,yV85d):
    yV85.append((item1+ratb*item2+ratc*item3+ratd*item4)/(1+ratb+ratc+ratd))

# %%
stderror85=2*np.std(midVel85)/np.sqrt(64)
errorLine85X = [(xV85[22]+xV85[23])/2,(xV85[22]+xV85[23])/2]
errorLine85Y = [(yV85[24]+yV85[23])/2-stderror85,(yV85[24]+yV85[23])/2+stderror85]

# %%
time = "{:09d}".format(int(360000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_50',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50b',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50b',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50b',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50c',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50c',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50c',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50d',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50d',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50d',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50e',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50e',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50e',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50f',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50f',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50f',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50g',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50g',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50g',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50h',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50h',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50h',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50i',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50i',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50i',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50j',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50j',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50j',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50k',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50k',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50k',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50l',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50l',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50l',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50m',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50m',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50m',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50n',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50n',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50n',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50o',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50o',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50o',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50p',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4_nowall_50p',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/low4_nowall_50p',time,nbins=28,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-27 09:25:20,090 Parameters: current_time              = 1.7919045032823007e-08
# yt : [INFO     ] 2022-04-27 09:25:20,091 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2022-04-27 09:25:20,092 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-27 09:25:20,093 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-27 09:25:24,424 Parameters: current_time              = 1.7919045032823007e-08
# yt : [INFO     ] 2022-04-27 09:25:24,426 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2022-04-27 09:25:24,427 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-27 09:25:24,428 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-27 09:25:26,444 Parameters: current_time              = 1.7919045032823007e-08
# ...

# %%
yC50a=[]
yA50a=[]
yV50a=[]
xC50a=X1b
xA50a=X1b
xV50a=X3b
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 0
ratm = 1
ratn = 1
rato = 1
ratp = 1
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1m,Y1n,Y1o,Y1p):
    yC50a.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2m,Y2n,Y2o,Y2p):
    yA50a.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3m,Y3n,Y3o,Y3p):
    yV50a.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVel50=[]
midVel50.append((Y3a[14]+Y3a[13])/2)
midVel50.append((Y3b[14]+Y3b[13])/2)
midVel50.append((Y3c[14]+Y3c[13])/2)
midVel50.append((Y3d[14]+Y3d[13])/2)
midVel50.append((Y3e[14]+Y3e[13])/2)
midVel50.append((Y3f[14]+Y3f[13])/2)
midVel50.append((Y3g[14]+Y3g[13])/2)
midVel50.append((Y3h[14]+Y3h[13])/2)
midVel50.append((Y3i[14]+Y3a[13])/2)
midVel50.append((Y3j[14]+Y3b[13])/2)
midVel50.append((Y3k[14]+Y3c[13])/2)
#midVel50.append((Y3l[14]+Y3d[13])/2)
midVel50.append((Y3m[14]+Y3e[13])/2)
midVel50.append((Y3n[14]+Y3f[13])/2)
midVel50.append((Y3o[14]+Y3g[13])/2)
midVel50.append((Y3p[14]+Y3h[13])/2)

# %%
time = "{:09d}".format(int(360000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50b',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50b',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50b',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50c',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50c',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50c',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50d',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50d',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50d',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50e',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50e',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50e',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50f',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50f',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50f',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50g',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50g',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50g',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50h',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50h',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50h',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50i',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50i',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50i',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50j',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50j',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50j',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50k',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50k',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50k',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50l',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50l',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50l',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50m',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50m',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50m',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50n',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50n',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50n',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50o',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50o',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50o',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(360000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50p',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50p',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2/low4_nowall_50p',time,nbins=28,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-27 09:27:45,941 Parameters: current_time              = 1.7919045032823007e-08
# yt : [INFO     ] 2022-04-27 09:27:45,942 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2022-04-27 09:27:45,943 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-27 09:27:45,944 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-27 09:27:50,352 Parameters: current_time              = 1.7919045032823007e-08
# yt : [INFO     ] 2022-04-27 09:27:50,353 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2022-04-27 09:27:50,355 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-27 09:27:50,356 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-27 09:27:52,385 Parameters: current_time              = 1.7919045032823007e-08
# ...

# %%
yC50b=[]
yA50b=[]
yV50b=[]
xC50b=X1b
xA50b=X1b
xV50b=X3b
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 0
ratm = 1
ratn = 1
rato = 1
ratp = 1
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1m,Y1n,Y1o,Y1p):
    yC50b.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2m,Y2n,Y2o,Y2p):
    yA50b.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3m,Y3n,Y3o,Y3p):
    yV50b.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVel50.append((Y3a[14]+Y3a[13])/2)
midVel50.append((Y3b[14]+Y3b[13])/2)
midVel50.append((Y3c[14]+Y3c[13])/2)
midVel50.append((Y3d[14]+Y3d[13])/2)
midVel50.append((Y3e[14]+Y3e[13])/2)
midVel50.append((Y3f[14]+Y3f[13])/2)
midVel50.append((Y3g[14]+Y3g[13])/2)
midVel50.append((Y3h[14]+Y3h[13])/2)
midVel50.append((Y3i[14]+Y3a[13])/2)
midVel50.append((Y3j[14]+Y3b[13])/2)
midVel50.append((Y3k[14]+Y3c[13])/2)
#midVel50.append((Y3l[14]+Y3d[13])/2)
midVel50.append((Y3m[14]+Y3e[13])/2)
midVel50.append((Y3n[14]+Y3f[13])/2)
midVel50.append((Y3o[14]+Y3g[13])/2)
midVel50.append((Y3p[14]+Y3h[13])/2)

# %%
time = "{:09d}".format(int(290000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50b',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50b',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50b',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50c',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50c',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50c',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50d',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50d',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50d',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50e',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50e',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50e',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50f',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50f',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50f',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50g',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50g',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50g',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50h',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50h',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50h',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50i',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50i',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50i',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50j',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50j',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50j',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50k',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50k',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50k',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50l',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50l',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50l',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50m',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50m',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50m',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50n',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50n',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50n',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50o',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50o',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50o',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(290000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50p',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50p',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2b/low4_nowall_50p',time,nbins=28,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-27 09:29:58,332 Parameters: current_time              = 1.4419045032865359e-08
# yt : [INFO     ] 2022-04-27 09:29:58,334 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2022-04-27 09:29:58,335 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-27 09:29:58,336 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-27 09:30:01,108 Parameters: current_time              = 1.4419045032865359e-08
# yt : [INFO     ] 2022-04-27 09:30:01,108 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2022-04-27 09:30:01,109 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-27 09:30:01,110 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-27 09:30:02,246 Parameters: current_time              = 1.4419045032865359e-08
# ...

# %%
yC50c=[]
yA50c=[]
yV50c=[]
xC50c=X1b
xA50c=X1b
xV50c=X3b
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 15/19
ratm = 1
ratn = 1
rato = 1
ratp = 1
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1l,Y1k,Y1m,Y1n,Y1o,Y1p):
    yC50c.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yA50c.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yV50c.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVel50.append((Y3a[14]+Y3a[13])/2)
midVel50.append((Y3b[14]+Y3b[13])/2)
midVel50.append((Y3c[14]+Y3c[13])/2)
midVel50.append((Y3d[14]+Y3d[13])/2)
midVel50.append((Y3e[14]+Y3e[13])/2)
midVel50.append((Y3f[14]+Y3f[13])/2)
midVel50.append((Y3g[14]+Y3g[13])/2)
midVel50.append((Y3h[14]+Y3h[13])/2)
midVel50.append((Y3i[14]+Y3a[13])/2)
midVel50.append((Y3j[14]+Y3b[13])/2)
midVel50.append((Y3k[14]+Y3c[13])/2)
midVel50.append((Y3l[14]+Y3d[13])/2)
midVel50.append((Y3m[14]+Y3e[13])/2)
midVel50.append((Y3n[14]+Y3f[13])/2)
midVel50.append((Y3o[14]+Y3g[13])/2)
midVel50.append((Y3p[14]+Y3h[13])/2)

# %%
time = "{:09d}".format(int(250000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(250000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50b',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50b',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50b',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50c',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50c',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50c',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50d',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50d',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50d',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50e',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50e',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50e',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50f',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50f',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50f',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50g',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50g',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50g',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50h',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50h',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50h',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(240000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50i',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50i',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50i',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(310000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50j',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50j',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50j',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(310000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50k',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50k',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50k',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(260000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50l',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50l',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50l',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(320000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50m',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50m',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50m',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(320000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50n',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50n',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50n',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(310000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50o',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50o',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50o',time,nbins=28,field="averaged_meanx")

time = "{:09d}".format(int(300000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50p',time,nbins=112,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50p',time,nbins=112,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall2c/low4_nowall_50p',time,nbins=28,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-27 09:31:23,127 Parameters: current_time              = 1.2419045032889561e-08
# yt : [INFO     ] 2022-04-27 09:31:23,128 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2022-04-27 09:31:23,129 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-27 09:31:23,129 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-27 09:31:27,305 Parameters: current_time              = 1.2419045032889561e-08
# yt : [INFO     ] 2022-04-27 09:31:27,306 Parameters: domain_dimensions         = [112 112 112]
# yt : [INFO     ] 2022-04-27 09:31:27,307 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-27 09:31:27,308 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-27 09:31:29,391 Parameters: current_time              = 1.2419045032889561e-08
# ...

# %%
yC50d=[]
yA50d=[]
yV50d=[]
xC50d=X1b
xA50d=X1b
xV50d=X3b
ratb = 15/15
ratc = 20/15
ratd = 20/15
rate = 20/15
ratf = 20/15
ratg = 20/15
rath = 20/15
rati = 14/15
ratj = 21/15
ratk = 21/15
ratl = 16/15
ratm = 22/15
ratn = 22/15
rato = 21/15
ratp = 20/15
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1l,Y1k,Y1m,Y1n,Y1o,Y1p):
    yC50d.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2l,Y2k,Y2m,Y2n,Y2o,Y2p):
    yA50d.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yV50d.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVel50.append((Y3a[14]+Y3a[13])/2)
midVel50.append((Y3b[14]+Y3b[13])/2)
midVel50.append((Y3c[14]+Y3c[13])/2)
midVel50.append((Y3d[14]+Y3d[13])/2)
midVel50.append((Y3e[14]+Y3e[13])/2)
midVel50.append((Y3f[14]+Y3f[13])/2)
midVel50.append((Y3g[14]+Y3g[13])/2)
midVel50.append((Y3h[14]+Y3h[13])/2)
midVel50.append((Y3i[14]+Y3a[13])/2)
midVel50.append((Y3j[14]+Y3b[13])/2)
midVel50.append((Y3k[14]+Y3c[13])/2)
midVel50.append((Y3l[14]+Y3d[13])/2)
midVel50.append((Y3m[14]+Y3e[13])/2)
midVel50.append((Y3n[14]+Y3f[13])/2)
midVel50.append((Y3o[14]+Y3g[13])/2)
midVel50.append((Y3p[14]+Y3h[13])/2)

# %%
yC50=[]
yA50=[]
yV50=[]
xC50=X1b
xA50=X1b
xV50=X3b

#ratb=1
ratb=0
ratc=300/390
ratd=307/390

for (item1,item3,item4) in zip(yC50a,yC50c,yC50d):
    yC50.append((item1+ratc*item3+ratd*item4)/(1+ratb+ratc+ratd))

for (item1,item3,item4) in zip(yA50a,yA50c,yA50d):
    yA50.append((item1+ratc*item3+ratd*item4)/(1+ratb+ratc+ratd))
    
for (item1,item3,item4) in zip(yV50a,yV50c,yV50d):
    yV50.append((item1+ratc*item3+ratd*item4)/(1+ratb+ratc+ratd))

# %%
stderror50=2*np.std(midVel50)/np.sqrt(48)
errorLine50X = [(xV50[14]+xV50[15])/2 - (xV50[15]-xV50[14])/2,(xV50[14]+xV50[15])/2 - (xV50[15]-xV50[14])/2]
errorLine50Y = [(yV50[14]+yV50[13])/2-stderror50,(yV50[14]+yV50[13])/2+stderror50]

# %%
yA50d
# Out:
# [-0.08562597346412616,
#  -1.7030649506329105,
#  -4.492694315624565,
#  -6.931218875466998,
#  -8.88345469833038,
#  -10.498579754949613,
#  -11.78474607920635,
#  -12.950864667090023,
#  -13.846361890395691,
#  -14.569718644546878,
#  -15.119560126321442,
#  -15.882363787623616,
#  -16.364941920961527,
#  -16.728698179137545,
#  -16.914473919440812,
#  -17.091424689189513,
#  -17.38917385564894,
#  -17.665784057990493,
#  -17.89346884036328,
#  -17.935423237557913,
#  -18.080398567822904,
#  -18.220394962928356,
#  -18.520272478383816,
#  -18.582883052651614,
#  -18.734606806755234,
#  -18.861241873002406,
#  -18.867725129365798,
#  -18.746716183407138,
#  -18.775363085228793,
#  -18.939979116155303,
#  -19.045876928796634,
#  -19.111691993315443,
#  -19.07450460647788,
#  -18.91999047732644,
#  -18.965107179022148,
#  -18.982663116831862,
#  -19.20276553996615,
#  -19.224028422937355,
#  -19.24205447493708,
#  -19.407491396506263,
#  -19.409427891728086,
#  -19.26891587754287,
# ...

# %%
time = "{:09d}".format(int(170000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowall',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowall',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowall',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallb',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallb',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallb',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallc',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallc',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallc',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalld',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalld',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalld',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalle',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalle',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalle',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallf',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallf',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallf',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallg',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallg',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallg',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallh',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallh',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallh',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalli',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalli',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalli',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallj',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallj',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallj',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallk',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallk',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallk',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalll',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalll',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalll',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallm',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallm',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallm',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalln',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalln',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalln',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallo',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallo',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallo',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallp',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallp',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallp',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 20:05:18,834 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:05:18,835 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:05:18,836 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:05:18,838 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:05:34,538 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:05:34,539 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:05:34,540 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:05:34,541 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:05:46,586 Parameters: current_time              = 8.419045032937965e-09
# ...

# %%
yCNWa=[]
yANWa=[]
yVNWa=[]
xCNWa=X1b
xANWa=X1b
xVNWa=X3b
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yCNWa.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yANWa.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yVNWa.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVelNW=[]
midVelNW.append((Y3a[28]+Y3a[27])/2)
midVelNW.append((Y3b[28]+Y3b[27])/2)
midVelNW.append((Y3c[28]+Y3c[27])/2)
midVelNW.append((Y3d[28]+Y3d[27])/2)
midVelNW.append((Y3e[28]+Y3e[27])/2)
midVelNW.append((Y3f[28]+Y3f[27])/2)
midVelNW.append((Y3g[28]+Y3g[27])/2)
midVelNW.append((Y3h[28]+Y3h[27])/2)
midVelNW.append((Y3i[28]+Y3i[27])/2)
midVelNW.append((Y3j[28]+Y3j[27])/2)
midVelNW.append((Y3k[28]+Y3k[27])/2)
midVelNW.append((Y3l[28]+Y3l[27])/2)
midVelNW.append((Y3m[28]+Y3m[27])/2)
midVelNW.append((Y3n[28]+Y3n[27])/2)
midVelNW.append((Y3o[28]+Y3o[27])/2)
midVelNW.append((Y3p[28]+Y3p[27])/2)

# %%
time = "{:09d}".format(int(170000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowall',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowall',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowall',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallb',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallb',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallb',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallc',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallc',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallc',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(150000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalld',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalld',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalld',time,nbins=56,field="averaged_meanx")

#time = "{:09d}".format(int(170000))
#X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalle',time,nbins=224,field="chargeDensityMeanSpecies00000")
#X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalle',time,nbins=224,field="chargeDensityMeanSpecies00001")
#X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalle',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallf',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallf',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallf',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallg',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallg',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallg',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallh',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallh',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallh',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalli',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalli',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalli',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallj',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallj',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallj',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallk',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallk',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallk',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalll',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalll',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalll',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallm',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallm',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallm',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalln',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalln',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalln',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallo',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallo',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallo',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallp',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallp',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallp',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 20:13:56,349 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:13:56,351 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:13:56,352 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:13:56,353 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:14:12,973 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:14:12,974 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:14:12,976 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:14:12,977 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:14:25,312 Parameters: current_time              = 8.419045032937965e-09
# ...

# %%
yCNWb=[]
yANWb=[]
yVNWb=[]
xCNWb=X1b
xANWb=X1b
xVNWb=X3b
ratb = 1
ratc = 1
ratd = 5/7
rate = 0
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yCNWb.append((item1+ratb*item2+ratc*item3+ratd*item4+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yANWb.append((-item1-ratb*item2-ratc*item3-ratd*item4-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yVNWb.append((item1+ratb*item2+ratc*item3+ratd*item4+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVelNW=[]
midVelNW.append((Y3a[28]+Y3a[27])/2)
midVelNW.append((Y3b[28]+Y3b[27])/2)
midVelNW.append((Y3c[28]+Y3c[27])/2)
midVelNW.append((Y3d[28]+Y3d[27])/2)
#midVelNW.append((Y3e[28]+Y3e[27])/2)
midVelNW.append((Y3f[28]+Y3f[27])/2)
midVelNW.append((Y3g[28]+Y3g[27])/2)
midVelNW.append((Y3h[28]+Y3h[27])/2)
midVelNW.append((Y3i[28]+Y3i[27])/2)
midVelNW.append((Y3j[28]+Y3j[27])/2)
midVelNW.append((Y3k[28]+Y3k[27])/2)
midVelNW.append((Y3l[28]+Y3l[27])/2)
midVelNW.append((Y3m[28]+Y3m[27])/2)
midVelNW.append((Y3n[28]+Y3n[27])/2)
midVelNW.append((Y3o[28]+Y3o[27])/2)
midVelNW.append((Y3p[28]+Y3p[27])/2)

# %%
time = "{:09d}".format(int(170000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallq',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallq',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallq',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallr',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallr',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallr',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalls',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalls',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowalls',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallt',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallt',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallt',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallu',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallu',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallu',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallv',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallv',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallv',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallw',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallw',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallw',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallx',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallx',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallx',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowally',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowally',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowally',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallz',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallz',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallz',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallza',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallza',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallza',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzb',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzb',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzb',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzc',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzc',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzc',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzd',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzd',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzd',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallze',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallze',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallze',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzf',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzf',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzf',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 20:22:06,867 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:22:06,868 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:22:06,869 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:22:06,871 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:22:22,955 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:22:22,956 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:22:22,958 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:22:22,959 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:22:35,323 Parameters: current_time              = 8.419045032937965e-09
# ...

# %%
yCNWc=[]
yANWc=[]
yVNWc=[]
xCNWc=X1b
xANWc=X1b
xVNWc=X3b
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yCNWc.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yANWc.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yVNWc.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVelNW.append((Y3a[28]+Y3a[27])/2)
midVelNW.append((Y3b[28]+Y3b[27])/2)
midVelNW.append((Y3c[28]+Y3c[27])/2)
midVelNW.append((Y3d[28]+Y3d[27])/2)
midVelNW.append((Y3e[28]+Y3e[27])/2)
midVelNW.append((Y3f[28]+Y3f[27])/2)
midVelNW.append((Y3g[28]+Y3g[27])/2)
midVelNW.append((Y3h[28]+Y3h[27])/2)
midVelNW.append((Y3i[28]+Y3i[27])/2)
midVelNW.append((Y3j[28]+Y3j[27])/2)
midVelNW.append((Y3k[28]+Y3k[27])/2)
midVelNW.append((Y3l[28]+Y3l[27])/2)
midVelNW.append((Y3m[28]+Y3m[27])/2)
midVelNW.append((Y3n[28]+Y3n[27])/2)
midVelNW.append((Y3o[28]+Y3o[27])/2)
midVelNW.append((Y3p[28]+Y3p[27])/2)

# %%
time = "{:09d}".format(int(170000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallq',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallq',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallq',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallr',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallr',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallr',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalls',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalls',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowalls',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(150000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallt',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallt',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallt',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallu',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallu',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallu',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(150000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallv',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallv',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallv',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallw',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallw',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallw',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallx',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallx',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallx',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(150000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowally',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowally',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowally',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallz',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallz',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallz',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallza',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallza',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallza',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzb',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzb',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzb',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzc',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzc',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzc',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzd',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzd',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzd',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallze',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallze',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallze',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzf',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzf',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzf',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 20:30:52,538 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:30:52,539 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:30:52,540 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:30:52,541 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:31:08,890 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:31:08,892 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:31:08,893 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:31:08,894 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:31:21,457 Parameters: current_time              = 8.419045032937965e-09
# ...

# %%
yCNWd=[]
yANWd=[]
yVNWd=[]
xCNWd=X1b
xANWd=X1b
xVNWd=X3b
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 5/7
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yCNWd.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yANWd.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yVNWd.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVelNW.append((Y3a[28]+Y3a[27])/2)
midVelNW.append((Y3b[28]+Y3b[27])/2)
midVelNW.append((Y3c[28]+Y3c[27])/2)
midVelNW.append((Y3d[28]+Y3d[27])/2)
midVelNW.append((Y3e[28]+Y3e[27])/2)
midVelNW.append((Y3f[28]+Y3f[27])/2)
midVelNW.append((Y3g[28]+Y3g[27])/2)
midVelNW.append((Y3h[28]+Y3h[27])/2)
midVelNW.append((Y3i[28]+Y3i[27])/2)
midVelNW.append((Y3j[28]+Y3j[27])/2)
midVelNW.append((Y3k[28]+Y3k[27])/2)
midVelNW.append((Y3l[28]+Y3l[27])/2)
midVelNW.append((Y3m[28]+Y3m[27])/2)
midVelNW.append((Y3n[28]+Y3n[27])/2)
midVelNW.append((Y3o[28]+Y3o[27])/2)
midVelNW.append((Y3p[28]+Y3p[27])/2)

# %%
time = "{:09d}".format(int(170000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzg',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzg',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzg',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzh',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzh',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzh',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzi',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzi',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzi',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzk',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzk',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzk',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzl',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzl',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzl',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzm',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzm',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzm',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzn',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzn',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzn',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzo',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzo',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzo',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzp',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzp',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzp',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzq',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzq',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzq',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzr',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzr',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzr',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzs',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzs',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzs',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzt',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzt',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzt',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzu',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzu',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzu',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzv',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzv',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzv',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzj',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzj',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzj',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 20:39:35,728 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:39:35,729 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:39:35,730 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:39:35,730 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:39:51,789 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:39:51,791 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:39:51,792 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:39:51,793 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:40:04,333 Parameters: current_time              = 8.419045032937965e-09
# ...

# %%
yCNWe=[]
yANWe=[]
yVNWe=[]
xCNWe=X1c
xANWe=X1c
xVNWe=X3c
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yCNWe.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yANWe.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yVNWe.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVelNW.append((Y3a[28]+Y3a[27])/2)
midVelNW.append((Y3b[28]+Y3b[27])/2)
midVelNW.append((Y3c[28]+Y3c[27])/2)
midVelNW.append((Y3d[28]+Y3d[27])/2)
midVelNW.append((Y3e[28]+Y3e[27])/2)
midVelNW.append((Y3f[28]+Y3f[27])/2)
midVelNW.append((Y3g[28]+Y3g[27])/2)
midVelNW.append((Y3h[28]+Y3h[27])/2)
midVelNW.append((Y3i[28]+Y3i[27])/2)
midVelNW.append((Y3j[28]+Y3j[27])/2)
midVelNW.append((Y3k[28]+Y3k[27])/2)
midVelNW.append((Y3l[28]+Y3l[27])/2)
midVelNW.append((Y3m[28]+Y3m[27])/2)
midVelNW.append((Y3n[28]+Y3n[27])/2)
midVelNW.append((Y3o[28]+Y3o[27])/2)
midVelNW.append((Y3p[28]+Y3p[27])/2)

# %%
time = "{:09d}".format(int(170000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzg',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzg',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzg',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzh',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzh',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzh',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzi',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzi',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzi',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzk',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzk',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzk',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzl',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzl',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzl',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzm',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzm',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzm',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzn',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzn',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzn',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzo',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzo',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzo',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzp',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzp',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzp',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzq',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzq',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzq',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzr',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzr',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzr',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzs',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzs',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzs',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzt',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzt',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzt',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzu',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzu',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzu',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzv',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzv',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzv',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(160000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzj',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzj',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzj',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 20:48:18,869 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:48:18,870 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:48:18,871 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:48:18,872 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:48:35,624 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:48:35,625 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:48:35,626 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:48:35,627 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:48:48,435 Parameters: current_time              = 8.419045032937965e-09
# ...

# %%
yCNWf=[]
yANWf=[]
yVNWf=[]
xCNWf=X1c
xANWf=X1c
xVNWf=X3c
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 6/7

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yCNWf.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yANWf.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yVNWf.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVelNW.append((Y3a[28]+Y3a[27])/2)
midVelNW.append((Y3b[28]+Y3b[27])/2)
midVelNW.append((Y3c[28]+Y3c[27])/2)
midVelNW.append((Y3d[28]+Y3d[27])/2)
midVelNW.append((Y3e[28]+Y3e[27])/2)
midVelNW.append((Y3f[28]+Y3f[27])/2)
midVelNW.append((Y3g[28]+Y3g[27])/2)
midVelNW.append((Y3h[28]+Y3h[27])/2)
midVelNW.append((Y3i[28]+Y3i[27])/2)
midVelNW.append((Y3j[28]+Y3j[27])/2)
midVelNW.append((Y3k[28]+Y3k[27])/2)
midVelNW.append((Y3l[28]+Y3l[27])/2)
midVelNW.append((Y3m[28]+Y3m[27])/2)
midVelNW.append((Y3n[28]+Y3n[27])/2)
midVelNW.append((Y3o[28]+Y3o[27])/2)
midVelNW.append((Y3p[28]+Y3p[27])/2)

# %%
time = "{:09d}".format(int(170000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzx',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzx',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzx',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzy',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzy',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzy',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzz',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzz',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzz',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(160000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzza',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzza',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzza',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzb',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzb',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzb',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzc',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzc',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzc',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzd',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzd',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzd',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzze',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzze',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzze',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzf',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzf',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzf',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzg',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzg',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzg',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzh',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzh',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzh',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzi',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzi',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzi',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzj',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzj',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzj',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzk',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzk',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzk',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzl',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzl',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzzl',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzw',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzw',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100/low4_nowallzw',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 20:57:19,991 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:57:19,992 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:57:19,994 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:57:19,995 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:57:36,698 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 20:57:36,699 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 20:57:36,700 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 20:57:36,702 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 20:57:49,572 Parameters: current_time              = 8.419045032937965e-09
# ...

# %%
yCNWg=[]
yANWg=[]
yVNWg=[]
xCNWg=X1d
xANWg=X1d
xVNWg=X3d
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yCNWg.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yANWg.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yVNWg.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVelNW.append((Y3a[28]+Y3a[27])/2)
midVelNW.append((Y3b[28]+Y3b[27])/2)
midVelNW.append((Y3c[28]+Y3c[27])/2)
midVelNW.append((Y3d[28]+Y3d[27])/2)
midVelNW.append((Y3e[28]+Y3e[27])/2)
midVelNW.append((Y3f[28]+Y3f[27])/2)
midVelNW.append((Y3g[28]+Y3g[27])/2)
midVelNW.append((Y3h[28]+Y3h[27])/2)
midVelNW.append((Y3i[28]+Y3i[27])/2)
midVelNW.append((Y3j[28]+Y3j[27])/2)
midVelNW.append((Y3k[28]+Y3k[27])/2)
midVelNW.append((Y3l[28]+Y3l[27])/2)
midVelNW.append((Y3m[28]+Y3m[27])/2)
midVelNW.append((Y3n[28]+Y3n[27])/2)
midVelNW.append((Y3o[28]+Y3o[27])/2)
midVelNW.append((Y3p[28]+Y3p[27])/2)

# %%
time = "{:09d}".format(int(170000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzx',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzx',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzx',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzy',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzy',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzy',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzz',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzz',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzz',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(160000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzza',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzza',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzza',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzb',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzb',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzb',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzc',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzc',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzc',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzd',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzd',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzd',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzze',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzze',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzze',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(150000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzf',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzf',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzf',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzg',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzg',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzg',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzh',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzh',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzh',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzi',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzi',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzi',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(160000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzj',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzj',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzj',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzk',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzk',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzk',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzl',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzl',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzzl',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(170000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzw',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzw',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/nowall100b/low4_nowallzw',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-04-26 21:14:15,065 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 21:14:15,065 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 21:14:15,066 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 21:14:15,067 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 21:14:30,738 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-04-26 21:14:30,739 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-04-26 21:14:30,741 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 21:14:30,743 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-04-26 21:14:44,032 Parameters: current_time              = 8.419045032937965e-09
# ...

# %%
yCNWh=[]
yANWh=[]
yVNWh=[]
xCNWh=X1d
xANWh=X1d
xVNWh=X3d
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yCNWh.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yANWh.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yVNWh.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVelNW.append((Y3a[28]+Y3a[27])/2)
midVelNW.append((Y3b[28]+Y3b[27])/2)
midVelNW.append((Y3c[28]+Y3c[27])/2)
midVelNW.append((Y3d[28]+Y3d[27])/2)
midVelNW.append((Y3e[28]+Y3e[27])/2)
midVelNW.append((Y3f[28]+Y3f[27])/2)
midVelNW.append((Y3g[28]+Y3g[27])/2)
midVelNW.append((Y3h[28]+Y3h[27])/2)
midVelNW.append((Y3i[28]+Y3i[27])/2)
midVelNW.append((Y3j[28]+Y3j[27])/2)
midVelNW.append((Y3k[28]+Y3k[27])/2)
midVelNW.append((Y3l[28]+Y3l[27])/2)
midVelNW.append((Y3m[28]+Y3m[27])/2)
midVelNW.append((Y3n[28]+Y3n[27])/2)
midVelNW.append((Y3o[28]+Y3o[27])/2)
midVelNW.append((Y3p[28]+Y3p[27])/2)

# %%
yCNW=[]
yANW=[]
yVNW=[]
xCNW=X1b
xANW=X1b
xVNW=X3b

for (item1,item2,item3,item4,item5,item6,item7,item8) in zip(yCNWa,yCNWb,yCNWc,yCNWd,yCNWe,yCNWf,yCNWg,yCNWh):
    yCNW.append((item1+item2+item3+item4+item5+item6+item7+item8)/8)

for (item1,item2,item3,item4,item5,item6,item7,item8) in zip(yANWa,yANWb,yANWc,yANWd,yANWe,yANWf,yANWg,yANWh):
    yANW.append((item1+item2+item3+item4+item5+item6+item7+item8)/8)
    
for (item1,item2,item3,item4,item5,item6,item7,item8) in zip(yVNWa,yVNWb,yVNWc,yVNWd,yVNWe,yVNWf,yVNWg,yVNWh):
    yVNW.append((item1+item2+item3+item4+item5+item6+item7+item8)/8)

# %%
stderrorNW=2*np.std(midVelNW)/np.sqrt(128)
errorLineNWX = [(xVNW[28]+xVNW[27])/2,(xVNW[28]+xVNW[27])/2]
errorLineNWY = [(yVNW[28]+yVNW[27])/2-stderrorNW,(yVNW[28]+yVNW[27])/2+stderrorNW]

# %%
time = "{:08d}".format(int(200000))
X1C, Y1C = return_y_plt('~/Downloads/lasttest',time,nbins=512,field="rho1")
X2C, Y2C = return_y_plt('~/Downloads/lasttest',time,nbins=512,field="rho2")
X3C,Y3C = return_y_plt('~/Downloads/lasttest',time,nbins=512,field="averaged_velx")
# Out:
# yt : [INFO     ] 2022-04-26 21:22:58,135 Parameters: current_time              = 5.000000000012922e-10
# yt : [INFO     ] 2022-04-26 21:22:58,136 Parameters: domain_dimensions         = [ 32 512   1]
# yt : [INFO     ] 2022-04-26 21:22:58,136 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 21:22:58,137 Parameters: domain_right_edge         = [3.75e-08 6.00e-07 1.00e+00]
# yt : [INFO     ] 2022-04-26 21:22:58,298 Parameters: current_time              = 5.000000000012922e-10
# yt : [INFO     ] 2022-04-26 21:22:58,298 Parameters: domain_dimensions         = [ 32 512   1]
# yt : [INFO     ] 2022-04-26 21:22:58,299 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-26 21:22:58,300 Parameters: domain_right_edge         = [3.75e-08 6.00e-07 1.00e+00]
# yt : [INFO     ] 2022-04-26 21:22:58,463 Parameters: current_time              = 5.000000000012922e-10
# ...

# %%
def mirrorAv(arr):
    l = len(arr);
    out=[]
    for i in range(l):
        out.append((arr[i]+arr[l-1-i])/2);
    return out

# %%
kb=1.38064852e-16
T=300
eps= 586.66e-21
q=1.6e-19
n0=(yCNWnorm[112])+(yANWnorm[112])
#rho0M=q*Y1C[256]/3.82e-23 - q*Y2C[256]/5.89e-23
ld=(q*n0/(eps*kb*T))**(-0.5)
eta=0.4e-2
sigma=7.57584366489012e11*eps
E=5.5e13


#n02=sigma*(-math.exp(3e-7/ld)-math.exp(3e-7/ld))/ld
#n0= ((sigma**2)*q)/(kb*T*eps)
LL=40
xT=np.linspace(0,6e-7,LL)
YT=[]
for i in range(LL):
    if i<LL/2:
        val=((sigma*ld*E)/eta)*(1-math.exp(-xT[i]/ld))
        YT.append(val)
    else:
        val=((sigma*ld*E)/eta)*(1-math.exp(-(6e-7-xT[i])/ld))
        YT.append(val)

#print(n0)
#print(rho0M)

# %%
#dx100=(6e-7)/len(yC100)
#r1=sum(yC100)*dx100*(6e-7)*(6e-7)
#c1=24*q
#rat=c1/r1
#l=len(yC100)
#yC100norm=[]
#for i in range(l):
#    yC100norm.append(yC100[i]*rat);
q=1.6e-19
    
dxNW=(6e-7)/len(yCNW)
r1=sum(yCNW)*dxNW*(6e-7)*(6e-7)
c1=24*q
rat=c1/r1
l=len(yCNW)
yCNWnorm=[]
for i in range(l):
    yCNWnorm.append(yCNW[i]*rat);
    
dxNW=(6e-7)/len(yANW)
r1=sum(yANW)*dxNW*(6e-7)*(6e-7)
c1=22*q
rat=c1/r1
l=len(yANW)
yANWnorm=[]
for i in range(l):
    yANWnorm.append(yANW[i]*rat);

# %%
ld=(q*n0/(eps*kb*T))**(-0.5)
lgc=2*kb*T*eps/(q*sigma)

print(ld/6e-7)
print(lgc/6e-7)
# Out:
# 0.1057584310802254
# 1.1390220854201267

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

#ax1.plot(xC100,mirrorAv(yC100norm),color='red',linewidth=2, label='DISCOS cation')
#ax1.plot(xA100,mirrorAv(yA100norm),color='blue',linewidth=2, label='DISCOS anion')
ax1.plot(xCNW,mirrorAv(yCNWnorm),color='red',linewidth=2, label='DISCOS')
ax1.plot(xANW,mirrorAv(yANWnorm),color='blue',linewidth=2, label='DISCOS')
ax1.plot(X1C,mirrorAv(q*Y1C/3.82e-23),color='red',linewidth=2,linestyle='dashed',label='PNP cation')
ax1.plot(X2C,mirrorAv(q*Y2C/5.89e-23),color='blue',linewidth=2,linestyle='dashed',label='PNP anion')


ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$|\varrho|$", fontsize=30,rotation=0, labelpad=15)
ax1.set_ylim([-1,26])
ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.55,0.10),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)

Xm=[0.5e-7,1.5e-7]
Ym=[3000,3000]

ax2 = fig.add_subplot(1,2,2)
#ax2.plot(xV100,mirrorAv(yV100),color='black',linewidth=2, label='DISCOS')
#ax2.plot(errorLine100X,errorLine100Y,color='black',linewidth=2)
ax2.plot(xVNW,mirrorAv(yVNW),color='black',linewidth=2, label='DISCOS')
ax2.plot(errorLineNWX,errorLineNWY,color='black',linewidth=2)
#ax2.plot(X3a,Y3l,color='black',linewidth=2,linestyle='dashdot', label='DISCOS - Flat Wall S')
ax2.plot(X3C,mirrorAv(Y3C),color='black',linewidth=2,linestyle='dashed', label='PNP')
ax2.plot(xT,mirrorAv(YT),color='black',linewidth=2,linestyle='dotted', label='Theory')

ax2.set_xlabel(r'$y$', fontsize=30)
ax2.set_ylabel(r"$v_x$", fontsize=30, labelpad=15,rotation=0)
ax2.set_ylim([-15,620])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.55,0.10),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("EO5_raw.svg", bbox_inches = 'tight', pad_inches = 0.05)

# %%
Y1d
# Out:
# array([0.00488299, 0.0046629 , 0.0045041 , 0.00438861, 0.00430425,
#        0.00424253, 0.00419743, 0.00416459, 0.00414082, 0.00412375,
#        0.00411164, 0.00410319, 0.00409742, 0.00409365, 0.00409138,
#        0.00409032, 0.00409032, 0.00409138, 0.00409365, 0.00409742,
#        0.00410319, 0.00411164, 0.00412375, 0.00414082, 0.00416459,
#        0.00419743, 0.00424253, 0.00430425, 0.00438861, 0.0045041 ,
#        0.0046629 , 0.00488299])

# %%
Y2d
# Out:
# array([0.00517393, 0.00541887, 0.00561206, 0.00576323, 0.00588091,
#        0.00597222, 0.00604295, 0.00609767, 0.00613995, 0.00617253,
#        0.0061975 , 0.00621639, 0.00623035, 0.00624018, 0.00624646,
#        0.00624951, 0.00624951, 0.00624646, 0.00624018, 0.00623035,
#        0.00621639, 0.0061975 , 0.00617253, 0.00613995, 0.00609767,
#        0.00604295, 0.00597222, 0.00588091, 0.00576323, 0.00561206,
#        0.00541887, 0.00517393])

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(xCNW,mirrorAv(yCNWnorm),color='red',linewidth=2, label='Cation 100\%')
ax1.plot(xANW,mirrorAv(yANWnorm),color='blue',linewidth=2, label='Anion 100\%')
ax1.plot(xC85,mirrorAv(yC85norm),color='red',linewidth=2,linestyle='dashed', label='Cation 85\%')
ax1.plot(xA85,mirrorAv(yA85norm),color='blue',linewidth=2,linestyle='dashed', label='Anion 85\%')
ax1.plot(xC50,mirrorAv(yC50norm),color='red',linewidth=2,linestyle='dotted', label='Cation 50\%')
ax1.plot(xA50,mirrorAv(yA50norm),color='blue',linewidth=2,linestyle='dotted', label='Anion 50\%')


ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$|\varrho|$", fontsize=30,rotation=0, labelpad=15)
ax1.set_ylim([-1,24])
ax1.set_xlim([-0.1e-7,2.5e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.63,0.05),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)

Xm=[0.5e-7,1.5e-7]
Ym=[3000,3000]

ax2 = fig.add_subplot(1,2,2)
ax2.plot(xVNW,mirrorAv(yVNW),color='black',linewidth=2, label='100\%')
ax2.plot(xV85,mirrorAv(yV85),color='black',linewidth=2,linestyle='dashed', label='85\%')
ax2.plot(xV50,mirrorAv(yV50),color='black',linewidth=2,linestyle='dotted', label='50\%')
ax2.plot(errorLineNWX,errorLineNWY,color='black',linewidth=2)
ax2.plot(errorLine85X,errorLine85Y,color='black',linewidth=2,linestyle='dashed')
ax2.plot(errorLine50X,errorLine50Y,color='black',linewidth=2,linestyle='dotted')


ax2.set_xlabel(r'$y$', fontsize=30)
ax2.set_ylabel(r"$v_x$", fontsize=30, labelpad=15,rotation=0)
ax2.set_ylim([-10,595])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.62,0.1),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("EO6_4point.svg", bbox_inches = 'tight', pad_inches = 0.05)

# %%
q=1.6e-19

#dx100=(6e-7)/len(yC100)
#r1=sum(yC100)*dx100*(6e-7)*(6e-7)
#c1=24*q
#rat=c1/r1
#l=len(yC100)
#yC100norm=[]
#for i in range(l):
#    yC100norm.append(yC100[i]*rat);
    
dxNW=(6e-7)/len(yCNW)
r1=sum(yCNW)*dxNW*(6e-7)*(6e-7)
c1=24*q
rat=c1/r1
l=len(yCNW)
yCNWnorm=[]
for i in range(l):
    yCNWnorm.append(yCNW[i]*rat);
    
dxNW=(6e-7)/len(yANW)
r1=sum(yANW)*dxNW*(6e-7)*(6e-7)
c1=22*q
rat=c1/r1
l=len(yANW)
yANWnorm=[]
for i in range(l):
    yANWnorm.append(yANW[i]*rat);
    
#dx100=(6e-7)/len(yA100)
#r1=sum(yA100)*dx100*(6e-7)*(6e-7)
#c1=22*q
#rat=c1/r1
#l=len(yA100)
#yA100norm=[]
#for i in range(l):
#    yA100norm.append(yA100[i]*rat);
    
dx85=(6e-7)/len(yC85)
r1=sum(yC85)*dx85*(6e-7)*(6e-7)
c1=24*q
rat=c1/r1
l=len(yC85)
yC85norm=[]
for i in range(l):
    yC85norm.append(yC85[i]*rat);
    
dx85=(6e-7)/len(yA85)
r1=sum(yA85)*dx85*(6e-7)*(6e-7)
c1=22*q
rat=c1/r1
l=len(yA85)
yA85norm=[]
for i in range(l):
    yA85norm.append(yA85[i]*rat);
    
dx50=(6e-7)/len(yC50)
r1=sum(yC50)*dx50*(6e-7)*(6e-7)
c1=24*q
rat=c1/r1
l=len(yC50)
yC50norm=[]
for i in range(l):
    yC50norm.append(yC50[i]*rat);
    
dx50=(6e-7)/len(yA50)
r1=sum(yA50)*dx50*(6e-7)*(6e-7)
c1=22*q
rat=c1/r1
l=len(yA50)
yA50norm=[]
for i in range(l):
    yA50norm.append(yA50[i]*rat);

# %%
yC50
# Out:
# [0.08960767662572892,
#  2.1747739398928125,
#  6.208554661722214,
#  9.98336974601775,
#  12.866524621816902,
#  14.938582823026147,
#  16.47797640779603,
#  17.67737348876504,
#  18.56328103563616,
#  19.338539060641644,
#  19.81369170094743,
#  20.21445905797983,
#  20.50540869457229,
#  20.65091835253642,
#  20.727118230596894,
#  20.818547700162487,
#  20.852366110397483,
#  20.86078799102425,
#  20.81081883846192,
#  20.69763476766626,
#  20.58375143831748,
#  20.573086353811195,
#  20.504764140194656,
#  20.46289088398623,
#  20.263067084328945,
#  20.175394602236434,
#  20.0403846794006,
#  19.972889183079467,
#  19.930116740439132,
#  19.98798746348462,
#  19.928078794078495,
#  19.86987370168585,
#  19.80001235737663,
#  19.72100236086021,
#  19.649574177033042,
#  19.543513227296103,
#  19.456316912267983,
#  19.339987064215002,
#  19.228618732632178,
#  19.305549351836937,
#  19.456251917555033,
#  19.473546759387947,
#  19.447000949962817,
#  19.42976067436325,
# ...

# %%
dx50=(6e-7)/len(yC50)
sum(yC50)*dx50*(6e-7)*(6e-7)
# Out:
# 4.0259883684147225e-18

# %%
len(yC85)/len(yC50)
# Out:
# 1.7142857142857142

# %%
len(yC85)
# Out:
# 192

# %%
len(yC50)
# Out:
# 112

# %%
sum(mirrorAv(yC100))
# Out:
# 5041.228254939349

# %%
24*q
# Out:
# 3.8399999999999996e-18

# %%
6-5.33322704
# Out:
# 0.6667729600000003

# %%
time = "{:09d}".format(int(170000))
X1S, Y1S = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4',time,nbins=192,field="chargeDensityInstantSpecies00000")
X2S, Y2S = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/low4',time,nbins=192,field="chargeDensityInstantSpecies00001")
X3S,Y3S = return_y_plt('~/coriProject/dladiges/EO_tests4/low4',time,nbins=48,field="averaged_velx")
# Out:
# yt : [INFO     ] 2022-01-03 14:09:08,697 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-01-03 14:09:08,698 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-01-03 14:09:08,700 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-03 14:09:08,701 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-01-03 14:09:24,489 Parameters: current_time              = 8.419045032937965e-09
# yt : [INFO     ] 2022-01-03 14:09:24,490 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-01-03 14:09:24,491 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-03 14:09:24,492 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-01-03 14:09:36,317 Parameters: current_time              = 8.419045032937965e-09
# ...

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(X1S,Y1S,color='red',linewidth=2, label='DISCOS cation snapshot')
ax1.plot(X2S,-Y2S,color='blue',linewidth=2, label='DISCOS anion snapshot')


ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$|\varrho|$", fontsize=30,rotation=0, labelpad=15)
ax1.set_ylim([-10,350])
ax1.set_xlim([-0.1e-7,3e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.05,0.85),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)

Xm=[0.5e-7,1.5e-7]
Ym=[3000,3000]

ax2 = fig.add_subplot(1,2,2)
ax2.plot(X3S,Y3S,color='black',linewidth=2, label='DISCOS velocity snapshot')

ax2.set_xlabel(r'$y$', fontsize=30)
ax2.set_ylabel(r"$v_x$", fontsize=30, labelpad=15,rotation=0)
ax2.set_ylim([-14000,25000])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.05,0.9),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("EO5_rawS.svg", bbox_inches = 'tight', pad_inches = 0.05)

# %%
time = "{:09d}".format(int(180000))
X1a, Y1a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2a, Y2a = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3a,Y3a = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1b, Y1b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4b',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2b, Y2b = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4b',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3b,Y3b = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4b',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1c, Y1c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4c',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2c, Y2c = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4c',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3c,Y3c = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4c',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1d, Y1d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4d',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2d, Y2d = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4d',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3d,Y3d = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4d',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1e, Y1e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4e',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2e, Y2e = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4e',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3e,Y3e = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4e',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1f, Y1f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4f',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2f, Y2f = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4f',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3f,Y3f = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4f',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1g, Y1g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4g',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2g, Y2g = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4g',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3g,Y3g = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4g',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1h, Y1h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4h',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2h, Y2h = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4h',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3h,Y3h = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4h',time,nbins=56,field="averaged_meanx")


time = "{:09d}".format(int(180000))
X1i, Y1i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4i',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2i, Y2i = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4i',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3i,Y3i = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4i',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1j, Y1j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4j',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2j, Y2j = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4j',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3j,Y3j = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4j',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1k, Y1k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4k',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2k, Y2k = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4k',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3k,Y3k = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4k',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1l, Y1l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4l',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2l, Y2l = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4l',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3l,Y3l = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4l',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1m, Y1m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4m',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2m, Y2m = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4m',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3m,Y3m = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4m',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1n, Y1n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4n',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2n, Y2n = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4n',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3n,Y3n = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4n',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1o, Y1o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4o',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2o, Y2o = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4o',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3o,Y3o = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4o',time,nbins=56,field="averaged_meanx")

time = "{:09d}".format(int(180000))
X1p, Y1p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4p',time,nbins=224,field="chargeDensityMeanSpecies00000")
X2p, Y2p = return_y_dens_cplt('~/coriProject/dladiges/EO_tests4/uncharged4p',time,nbins=224,field="chargeDensityMeanSpecies00001")
X3p,Y3p = return_y_plt('~/coriProject/dladiges/EO_tests4/uncharged4p',time,nbins=56,field="averaged_meanx")
# Out:
# yt : [INFO     ] 2022-03-02 12:11:39,411 Parameters: current_time              = 8.919045032931915e-09
# yt : [INFO     ] 2022-03-02 12:11:39,415 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-03-02 12:11:39,418 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-03-02 12:11:39,419 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-03-02 12:13:03,156 Parameters: current_time              = 8.919045032931915e-09
# yt : [INFO     ] 2022-03-02 12:13:03,157 Parameters: domain_dimensions         = [224 224 224]
# yt : [INFO     ] 2022-03-02 12:13:03,159 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-03-02 12:13:03,160 Parameters: domain_right_edge         = [6.e-07 6.e-07 6.e-07]
# yt : [INFO     ] 2022-03-02 12:14:14,757 Parameters: current_time              = 8.919045032931915e-09
# ...

# %%
yC100=[]
yA100=[]
yV100=[]
xC100=X1b
xA100=X1b
xV100=X3b
ratb = 1
ratc = 1
ratd = 1
rate = 1
ratf = 1
ratg = 1
rath = 1
rati = 1
ratj = 1
ratk = 1
ratl = 1
ratm = 1
ratn = 1
rato = 1
ratp = 1

for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y1a,Y1b,Y1c,Y1d,Y1e,Y1f,Y1g,Y1h,Y1i,Y1j,Y1k,Y1l,Y1m,Y1n,Y1o,Y1p):
    yC100.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y2a,Y2b,Y2c,Y2d,Y2e,Y2f,Y2g,Y2h,Y2i,Y2j,Y2k,Y2l,Y2m,Y2n,Y2o,Y2p):
    yA100.append((-item1-ratb*item2-ratc*item3-ratd*item4-rate*item5-ratf*item6-ratg*item7-rath*item8-rati*item9-ratj*item10-ratk*item11-ratl*item12-ratm*item13-ratn*item14-rato*item15-ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))
    
for (item1,item2,item3,item4,item5,item6,item7,item8,item9,item10,item11,item12,item13,item14,item15,item16) in zip(Y3a,Y3b,Y3c,Y3d,Y3e,Y3f,Y3g,Y3h,Y3i,Y3j,Y3k,Y3l,Y3m,Y3n,Y3o,Y3p):
    yV100.append((item1+ratb*item2+ratc*item3+ratd*item4+rate*item5+ratf*item6+ratg*item7+rath*item8+rati*item9+ratj*item10+ratk*item11+ratl*item12+ratm*item13+ratn*item14+rato*item15+ratp*item16)/(1+ratb+ratc+ratd+rate+ratf+ratg+rath+rati+ratj+ratk+ratl+ratm+ratn+rato+ratp))

# %%
midVel100=[]
midVel100.append((Y3a[28]+Y3a[27])/2)
midVel100.append((Y3b[28]+Y3b[27])/2)
midVel100.append((Y3c[28]+Y3c[27])/2)
midVel100.append((Y3d[28]+Y3d[27])/2)
midVel100.append((Y3e[28]+Y3e[27])/2)
midVel100.append((Y3f[28]+Y3f[27])/2)
midVel100.append((Y3g[28]+Y3g[27])/2)
midVel100.append((Y3h[28]+Y3h[27])/2)
midVel100.append((Y3i[28]+Y3i[27])/2)
midVel100.append((Y3j[28]+Y3j[27])/2)
midVel100.append((Y3k[28]+Y3k[27])/2)
midVel100.append((Y3l[28]+Y3l[27])/2)
midVel100.append((Y3m[28]+Y3m[27])/2)
midVel100.append((Y3n[28]+Y3n[27])/2)
midVel100.append((Y3o[28]+Y3o[27])/2)
midVel100.append((Y3p[28]+Y3p[27])/2)

# %%
stderror100=np.std(midVel100)/np.sqrt(32)
errorLine100X = [(xV100[28]+xV100[27])/2,(xV100[28]+xV100[27])/2]
errorLine100Y = [(yV100[28]+yV100[27])/2-stderror100,(yV100[28]+yV100[27])/2+stderror100]

# %%
dx100=(6e-7)/len(yC100)
r1=sum(yC100)*dx100*(6e-7)*(6e-7)
c1=24*q
rat=c1/r1
l=len(yC100)
yC100norm=[]
for i in range(l):
    yC100norm.append(yC100[i]*rat);

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(xC100,mirrorAv(yC100norm),color='red',linewidth=2, label='DISCOS cation')
ax1.plot(xA100,mirrorAv(yA100norm),color='blue',linewidth=2, label='DISCOS anion')


ax1.set_xlabel(r'$y$', fontsize=30)
ax1.set_ylabel(r"$|\varrho|$", fontsize=30,rotation=0, labelpad=15)
ax1.set_ylim([-4,180])
ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.63),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)

Xm=[0.5e-7,1.5e-7]
Ym=[3000,3000]

ax2 = fig.add_subplot(1,2,2)
ax2.plot(xV100,mirrorAv(yV100),color='black',linewidth=2, label='DISCOS')
ax2.plot(errorLine100X,errorLine100Y,color='black',linewidth=2)


ax2.set_xlabel(r'$y$', fontsize=30)
ax2.set_ylabel(r"$v_x$", fontsize=30, labelpad=15,rotation=0)
ax2.set_ylim([-50,1220])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.53,0.75),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

#fig.savefig("EO5_raw.svg", bbox_inches = 'tight', pad_inches = 0.05)
