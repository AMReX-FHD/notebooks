# %%
import yt
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import seaborn as sns

# %%
ds = yt.load('plt.Cavity00010')
ds.field_list
# Out:
# yt : [INFO     ] 2022-06-13 15:23:42,986 Parameters: current_time              = 0.017408426036316
# yt : [INFO     ] 2022-06-13 15:23:42,987 Parameters: domain_dimensions         = [16 16  1]
# yt : [INFO     ] 2022-06-13 15:23:42,988 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-13 15:23:42,989 Parameters: domain_right_edge         = [1. 1. 1.]
# [('boxlib', 'cost'),
#  ('boxlib', 'density-air'),
#  ('boxlib', 'density-air2'),
#  ('boxlib', 'frac-air'),
#  ('boxlib', 'frac-air2'),
#  ('boxlib', 'nrg-air'),
#  ('boxlib', 'nrg-air2'),
#  ('boxlib', 'tracer-air'),
#  ('boxlib', 'tracer-air2'),
#  ('boxlib', 'x_mom-air'),
#  ('boxlib', 'x_mom-air2'),
#  ('boxlib', 'y_mom-air'),
#  ('boxlib', 'y_mom-air2'),
#  ('boxlib', 'z_mom-air'),
#  ('boxlib', 'z_mom-air2')]

# %%
slc = yt.SlicePlot(ds,'z',('boxlib', 'x_mom-air'))
#slc.set_cmap(field=('struct_fact_Temp_Y1'), cmap="turbo")
slc.show()
# Out:
# yt : [INFO     ] 2022-06-13 15:25:53,210 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-13 15:25:53,211 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-13 15:25:53,212 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-13 15:25:53,213 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-13 15:25:53,216 Making a fixed resolution buffer of (('boxlib', 'x_mom-air')) 800 by 800
# yt : [WARNING  ] 2022-06-13 15:25:53,248 Plotting ('boxlib', 'x_mom-air'): Both positive and negative values. Min = -0.025757587199880354 dimensionless, Max = 0.025757392567781468 dimensionless.
# yt : [WARNING  ] 2022-06-13 15:25:53,249 Switching to symlog colorbar scaling.
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
pp = yt.ParticlePlot(ds,('boxlib', 'tracer-air'),('boxlib', 'tracer-air2'))
pp.show()
# Out:
# ---------------------------------------------------------------------------
# YTFieldNotFound                           Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 pp = yt.ParticlePlot(ds,('boxlib', 'tracer-air'),('boxlib', 'tracer-air2'))
#       2 pp.show()
#
# File ~/.pyenv/versions/3.9.13/lib/python3.9/site-packages/yt/visualization/particle_plots.py:602, in ParticlePlot(ds, x_field, y_field, z_fields, color, *args, **kwargs)
#     597     return ParticleProjectionPlot(ds, direction, z_fields, color, *args, **kwargs)
#     599 # Does not correspond to any valid PlotWindow-style plot,
#     600 # use ParticlePhasePlot instead
#     601 else:
# --> 602     return ParticlePhasePlot(dd, x_field, y_field, z_fields, color, *args, **kwargs)
#
# File ~/.pyenv/versions/3.9.13/lib/python3.9/site-packages/yt/visualization/particle_plots.py:410, in ParticlePhasePlot.__init__(self, data_source, x_field, y_field, z_fields, color, x_bins, y_bins, weight_field, deposition, fontsize, figure_size, shading)
#     407     self.splat_color = color
#     408     z_fields = [("all", "particle_ones")]
# --> 410 profile = create_profile(
#     411     data_source,
#     412     [x_field, y_field],
#     413     list(iter_fields(z_fields)),
#     414     n_bins=[x_bins, y_bins],
#     415     weight_field=weight_field,
#     416     deposition=deposition,
#     417 )
#     419 type(self)._initialize_instance(
#     420     self, data_source, profile, fontsize, figure_size, shading
#     421 )
#
# File ~/.pyenv/versions/3.9.13/lib/python3.9/site-packages/yt/data_objects/profiles.py:1273, in create_profile(data_source, bin_fields, fields, n_bins, extrema, logs, units, weight_field, accumulation, fractional, deposition, override_bins)
#    1271 bin_fields = data_source._determine_fields(bin_fields)
#    1272 fields = list(iter_fields(fields))
# -> 1273 is_pfield = [
#    1274     data_source.ds._get_field_info(f).sampling_type == "particle"
#    1275     for f in bin_fields + fields
#    1276 ]
#    1277 wf = None
#    1278 if weight_field is not None:
#
# File ~/.pyenv/versions/3.9.13/lib/python3.9/site-packages/yt/data_objects/profiles.py:1274, in <listcomp>(.0)
#    1271 bin_fields = data_source._determine_fields(bin_fields)
#    1272 fields = list(iter_fields(fields))
#    1273 is_pfield = [
# -> 1274     data_source.ds._get_field_info(f).sampling_type == "particle"
#    1275     for f in bin_fields + fields
#    1276 ]
#    1277 wf = None
#    1278 if weight_field is not None:
#
# File ~/.pyenv/versions/3.9.13/lib/python3.9/site-packages/yt/data_objects/static_output.py:826, in Dataset._get_field_info(self, ftype, fname)
#     825 def _get_field_info(self, ftype, fname=None):
# --> 826     field_info, is_ambiguous = self._get_field_info_helper(ftype, fname)
#     828     if is_ambiguous:
#     829         ft, fn = field_info.name
#
# File ~/.pyenv/versions/3.9.13/lib/python3.9/site-packages/yt/data_objects/static_output.py:904, in Dataset._get_field_info_helper(self, ftype, fname)
#     902             self._last_finfo = self.field_info[(ftype, fname)]
#     903             return self._last_finfo, is_ambiguous
# --> 904 raise YTFieldNotFound(field=INPUT, ds=self)
#
# YTFieldNotFound: Could not find field (('all', 'particle_ones'), None) in plt.Cavity00010.
