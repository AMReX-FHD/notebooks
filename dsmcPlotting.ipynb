# %%
import yt
import numpy as np
import math
import matplotlib.pyplot as plt
# Out:
# /usr/lib/python3.8/_collections_abc.py:666: MatplotlibDeprecationWarning: The global colormaps dictionary is no longer considered public API.
#   self[key]

# %%
def return_y_plt(folder,time,nbins,field="densityMean"):
    ds = yt.load(folder+time)
    ad = ds.all_data()
    plot = yt.ProfilePlot(ad,"x",[field],weight_field="cell_volume",x_log=False,y_log={field:False},n_bins=nbins)
    profile = plot.profiles[0]
    x = np.array(profile.x)
    y = np.array(profile[field])
    return x, y

# %%
time = "/pltcu0000"+"02000000/"
x1a, y1a = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="rhoMean_00")
x2a, y2a = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="rhoMean_01")

time = "/pltcu0000"+"05000000/"
x1b, y1b = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="rhoMean_00")
x2b, y2b = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="rhoMean_01")

time = "/pltprim0000"+"02000000/"
x5a, y5a = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="uMean")
x4a, y4a = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="rhoMean")
x3a, y3a = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="TMean")

time = "/pltprim0000"+"05000000/"
x5b, y5b = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="uMean")
x4b, y4b = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="rhoMean")
x3b, y3b = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="TMean")
# Out:
# yt : [INFO     ] 2022-05-17 12:53:35,397 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-17 12:53:35,398 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:53:35,399 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:53:35,400 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:53:37,553 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-17 12:53:37,554 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:53:37,555 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:53:37,556 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:53:38,852 Parameters: current_time              = 0.00014999996999523742
# yt : [INFO     ] 2022-05-17 12:53:38,854 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:53:38,855 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:53:38,856 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:53:40,992 Parameters: current_time              = 0.00014999996999523742
# yt : [INFO     ] 2022-05-17 12:53:40,993 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:53:40,994 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:53:40,995 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:53:42,285 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-17 12:53:42,286 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:53:42,288 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:53:42,289 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:53:44,424 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-17 12:53:44,425 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:53:44,427 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:53:44,429 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:53:45,622 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-17 12:53:45,623 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:53:45,624 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:53:45,625 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:53:46,929 Parameters: current_time              = 0.00014999996999523742
# yt : [INFO     ] 2022-05-17 12:53:46,930 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:53:46,934 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:53:46,935 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:53:49,090 Parameters: current_time              = 0.00014999996999523742
# yt : [INFO     ] 2022-05-17 12:53:49,091 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:53:49,092 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:53:49,093 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:53:50,296 Parameters: current_time              = 0.00014999996999523742
# yt : [INFO     ] 2022-05-17 12:53:50,297 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:53:50,299 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:53:50,300 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]

# %%
time = "/pltcu0000"+"00020000/"
x1a, y1a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_00")
x2a, y2a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_01")

time = "/pltcu0000"+"00015000/"
x1b, y1b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_00")
x2b, y2b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_01")

time = "/pltprim0000"+"00020000/"
x5a, y5a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="uMean")
x4a, y4a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean")
x3a, y3a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="TMean")

time = "/pltprim0000"+"00015000/"
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="uMean")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="TMean")
# Out:
# yt : [INFO     ] 2022-05-29 16:23:05,651 Parameters: current_time              = 5.999699999997919e-07
# yt : [INFO     ] 2022-05-29 16:23:05,652 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-29 16:23:05,654 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-29 16:23:05,656 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-29 16:23:07,933 Parameters: current_time              = 5.999699999997919e-07
# yt : [INFO     ] 2022-05-29 16:23:07,934 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-29 16:23:07,936 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-29 16:23:07,937 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-29 16:23:09,245 Parameters: current_time              = 4.499699999998865e-07
# yt : [INFO     ] 2022-05-29 16:23:09,247 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-29 16:23:09,248 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-29 16:23:09,249 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-29 16:23:11,500 Parameters: current_time              = 4.499699999998865e-07
# yt : [INFO     ] 2022-05-29 16:23:11,502 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-29 16:23:11,503 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-29 16:23:11,504 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-29 16:23:12,820 Parameters: current_time              = 5.999699999997919e-07
# yt : [INFO     ] 2022-05-29 16:23:12,822 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-29 16:23:12,823 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-29 16:23:12,824 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-29 16:23:15,082 Parameters: current_time              = 5.999699999997919e-07
# yt : [INFO     ] 2022-05-29 16:23:15,084 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-29 16:23:15,085 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-29 16:23:15,086 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-29 16:23:16,286 Parameters: current_time              = 5.999699999997919e-07
# yt : [INFO     ] 2022-05-29 16:23:16,287 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-29 16:23:16,288 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-29 16:23:16,289 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-29 16:23:17,613 Parameters: current_time              = 4.499699999998865e-07
# yt : [INFO     ] 2022-05-29 16:23:17,615 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-29 16:23:17,616 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-29 16:23:17,617 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-29 16:23:19,878 Parameters: current_time              = 4.499699999998865e-07
# yt : [INFO     ] 2022-05-29 16:23:19,880 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-29 16:23:19,881 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-29 16:23:19,882 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-29 16:23:21,162 Parameters: current_time              = 4.499699999998865e-07
# yt : [INFO     ] 2022-05-29 16:23:21,163 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-29 16:23:21,164 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-29 16:23:21,165 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]

# %%
nc=128
LL=3.84e-04
cs=LL/nc
xDSMC=np.linspace(0.5*cs,LL-0.5*cs,nc)

# %%
filename = '/home/drladiges/Downloads/profile_neq3.txt'
data = np.loadtxt(filename, delimiter=' ', skiprows=1, dtype=str)

LL=len(data)
xFHD=[]
yFHD1=[]
yFHD2=[]
yFHD3=[]
yFHD4=[]
for i in range(LL):
    val=float(data[i,0])
    xFHD.append(val)
    val1=float(data[i,1])
    val2=float(data[i,2])
    val3=float(data[i,3])    
    rho=float(data[i,4])
    yFHD1.append(val1)
    yFHD2.append(val2)
    yFHD3.append(val3)
    yFHD4.append(rho)

# %%
LL=len(x1a)
rhoSum=[]
for i in range(LL):
    val1=y1[i]
    val2=y2[i]
    rhoSum.append(val1+val2)
    
y1rev=y1[::-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6f1e30905952> in <module>
#       2 rhoSum=[]
#       3 for i in range(LL):
# ----> 4     val1=y1[i]
#       5     val2=y2[i]
#       6     rhoSum.append(val1+val2)
#
# NameError: name 'y1' is not defined

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(xDSMC,y1a,color='red',linewidth=2, label='DSMC spec 0')
ax1.plot(xDSMC, y2a,color='blue',linewidth=2, label='DSMC spec 1')
ax1.plot(xDSMC, y1a+y2a,color='green',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y1b,color='red',linewidth=2,linestyle='dashed', label='DSMC spec 0')
ax1.plot(xDSMC,y2b,color='blue',linewidth=2,linestyle='dashed', label='DSMC spec 1')
ax1.plot(xDSMC, y1b+y2b,color='green',linewidth=2, label='DSMC total')
ax1.plot([0,0.0004], [0.000658,0.000658],color='orange',linewidth=2)
ax1.plot([0,0.0004], [0.001316,0.001316],color='orange',linewidth=2)
#ax1.plot(xDSMC, y2b,color='blue',linewidth=2,linestyle='dashed', label='DSMC spec 1')
#ax1.plot(xDSMC, y1b+y2b,color='green',linewidth=2,linestyle='dashed', label='DSMC total')
#ax1.plot(xFHD,yFHD1,color='red',linewidth=2,linestyle='dashed', label='FHD spec 0')
#ax1.plot(xFHD,yFHD2,color='blue',linewidth=2,linestyle='dashed', label='FHD spec 1')
#ax1.plot(xFHD,yFHD4,color='black',linewidth=2,linestyle='dashed', label='FHD total')


ax1.set_xlabel(r'$x$', fontsize=30)
ax1.set_ylabel(r"$\rho$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.6),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


ax2 = fig.add_subplot(1,2,2)


#ax2.plot(xDSMC,y3a,color='purple',linewidth=2, label='DSMC')
ax2.plot(xDSMC,y3a,color='purple',linewidth=2, label='DSMC')
ax2.plot(xDSMC,y3b,color='purple',linewidth=2, label='DSMC',linestyle='dashed')
#ax2.plot(xDSMC,y3b,color='green',linewidth=2, label='2')
#ax2.plot(xDSMC,y3c,color='orange',linewidth=2, label='2 million development')
ax2.plot(xFHD,yFHD3,color='black',linewidth=2,linestyle='dashed', label='FHD')

ax2.set_xlabel(r'$x$', fontsize=30)
ax2.set_ylabel(r"$T$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.53,0.6),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("profiles.pdf", bbox_inches = 'tight', pad_inches = 0.05)

# %%
sum(y1a+y2a)/2
# Out:
# 0.08411762793479802

# %%
sum(yFHD4)
# Out:
# 0.08425534557969508

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

#ax1.plot(xDSMC,y1,color='red',linewidth=2, label='DSMC spec 1')
#ax1.plot(xDSMC,y2,color='blue',linewidth=2, label='DSMC spec 2')
#ax1.plot(xDSMC,y5a,color='green',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y5b,color='purple',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y5a,color='purple',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y5b,color='green',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y5c,color='orange',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y5c,color='blue',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y4b,color='purple',linewidth=2, label='DSMC total')
#ax1.plot(xFHD,yFHD4,color='red',linewidth=2,linestyle='dashed', label='FHD spec 1')
#ax1.plot(xDSMC,rhoSum,color='blue',linewidth=2,linestyle='dashed', label='DSMC sum')


ax1.set_xlabel(r'$x$', fontsize=30)
ax1.set_ylabel(r"$u$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.6),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


#ax2 = fig.add_subplot(1,2,2)

#ax2.plot(xDSMC,y3a,color='red',linewidth=2, label='DSMC')
#ax2.plot(xDSMC,y3b,color='black',linewidth=2, label='DSMC')
#ax2.plot(xDSMC,y3c,color='black',linewidth=2, label='DSMC')
#ax2.plot(xFHD,yFHD3,color='black',linewidth=2,linestyle='dashed', label='FHD')


#ax2.set_xlabel(r'$x$', fontsize=30)
#ax2.set_ylabel(r"$T$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
#ax2.tick_params(labelsize=20)
#ax2.legend(loc=(0.53,0.6),fontsize=20)
#ax2.xaxis.set_tick_params(width=1.5)
#ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("vel.pdf", bbox_inches = 'tight', pad_inches = 0.05)

# %%
filename = '/home/drladiges/Downloads/correl_neq1.txt'
data = np.loadtxt(filename, delimiter=' ', skiprows=1, dtype=str)



LL=len(data)
xFHDb=[]
yFHD1b=[]
yFHD2b=[]
yFHD3b=[]
for i in range(LL):
    val=float(data[i,0])
    xFHDb.append(val)
    #fhdcell=(xFHDb[1]-xFHDb[0])**3;
    #dsmccell=(3.84e-04/128)*((0.035e-4)**2);
    #cellRat=fhdcell/dsmccell
    
    val1=float(data[i,4])*cellRat
    val2=float(data[i,5])*cellRat
    val3=float(data[i,6])*cellRat
    yFHD1b.append(val1)
    yFHD2b.append(val2)
    yFHD3b.append(val3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-f36bdcb10738> in <module>
#      16     #cellRat=fhdcell/dsmccell
#      17
# ---> 18     val1=float(data[i,4])*cellRat
#      19     val2=float(data[i,5])*cellRat
#      20     val3=float(data[i,6])*cellRat
#
# NameError: name 'cellRat' is not defined

# %%
time = "/pltvar0000"+"00030000/"
x1b, y1b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho0*.rho0")
x2b, y2b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho1*.rho1")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho1*.rho0")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="T*.T")
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho*.rho")
# Out:
# yt : [INFO     ] 2022-05-15 21:24:44,700 Parameters: current_time              = 8.999699999996027e-07
# yt : [INFO     ] 2022-05-15 21:24:44,701 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-15 21:24:44,703 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-15 21:24:44,705 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-15 21:24:47,547 Parameters: current_time              = 8.999699999996027e-07
# yt : [INFO     ] 2022-05-15 21:24:47,549 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-15 21:24:47,550 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-15 21:24:47,551 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-15 21:24:48,782 Parameters: current_time              = 8.999699999996027e-07
# yt : [INFO     ] 2022-05-15 21:24:48,783 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-15 21:24:48,785 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-15 21:24:48,786 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-15 21:24:49,980 Parameters: current_time              = 8.999699999996027e-07
# yt : [INFO     ] 2022-05-15 21:24:49,982 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-15 21:24:49,983 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-15 21:24:49,984 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-15 21:24:51,176 Parameters: current_time              = 8.999699999996027e-07
# yt : [INFO     ] 2022-05-15 21:24:51,178 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-15 21:24:51,179 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-15 21:24:51,180 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]

# %%
time = "/pltvar0000"+"03000000/"
x1b, y1b = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="rho0*.rho0")
x2b, y2b = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="rho1*.rho1")
x3b, y3b = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="rho1*.rho0")
x4b, y4b = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="T*.T")
x5b, y5b = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="rho*.rho")
x6b, y6b = return_y_plt('~/giganScratch/DSMCtest3',time,nbins=128,field="rhoVar")
# Out:
# yt : [INFO     ] 2022-05-17 12:56:09,864 Parameters: current_time              = 8.999997000365736e-05
# yt : [INFO     ] 2022-05-17 12:56:09,865 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:56:09,867 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:56:09,868 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:56:12,150 Parameters: current_time              = 8.999997000365736e-05
# yt : [INFO     ] 2022-05-17 12:56:12,151 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:56:12,152 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:56:12,154 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:56:13,320 Parameters: current_time              = 8.999997000365736e-05
# yt : [INFO     ] 2022-05-17 12:56:13,321 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:56:13,322 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:56:13,323 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:56:14,510 Parameters: current_time              = 8.999997000365736e-05
# yt : [INFO     ] 2022-05-17 12:56:14,511 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:56:14,512 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:56:14,514 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:56:15,703 Parameters: current_time              = 8.999997000365736e-05
# yt : [INFO     ] 2022-05-17 12:56:15,704 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:56:15,706 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:56:15,708 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-17 12:56:16,889 Parameters: current_time              = 8.999997000365736e-05
# yt : [INFO     ] 2022-05-17 12:56:16,890 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-17 12:56:16,892 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 12:56:16,893 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.25)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(xDSMC,y5b,color='black',linewidth=2, label='DSMC')
#ax1.plot(xFHDb,yFHD1b,color='black',linewidth=2,linestyle='dashed', label='FHD')



ax1.set_xlabel(r'$x$', fontsize=20)
ax1.set_ylabel(r"$<\delta \rho_0^*\delta \rho_0>$", fontsize=30,rotation=90, labelpad=10)
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.7,0.8),fontsize=20)
#ax1.set_ylim([-100e-14,50e-14])
ax1.set_ylim([-100e-13,50e-13])
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)



ax2 = fig.add_subplot(1,2,2)

ax2.plot(xDSMC,y6b,color='black',linewidth=2, label='DSMC')
#ax2.plot(xFHDb,yFHD3b,color='black',linewidth=2,linestyle='dashed', label='FHD')

ax2.set_xlabel(r'$x$', fontsize=30)
ax2.set_ylabel(r"$<\delta \rho_1^*\delta \rho_0>$", fontsize=30,rotation=90, labelpad=10)
#ax2.set_ylabel(r"$<\delta T^*\delta T>$", fontsize=30,rotation=90, labelpad=10)
ax2.set_ylim([-1e-8,1e-8])
#ax1.set_xlim([-0.1e-7,2e-7])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.7,0.2),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("correlations.pdf", bbox_inches = 'tight', pad_inches = 0.05)

# %%
fhdcell=(xFHD[1]-xFHD[0])**3;
dsmccell=(3.84e-04/128)*((0.05e-4)*(0.07e-4));
cellRat=fhdcell/dsmccell

# %%
y4b
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
dsmccell
# Out:
# 3.675e-17

# %%
fhdcell
# Out:
# 2.2644984342943527e-16

# %%
fhdc=xFHD[2]-xFHD[1]

# %%
dsmcc=xDSMC[2]-xDSMC[1]

# %%
xFHD[0]
# Out:
# 3e-06

# %%
xDSMC[1]-dsmcc/2
# Out:
# 3.000000000000001e-06

# %%
xFHD[0]
# Out:
# 3e-06

# %%
xDSMC[127]
# Out:
# 0.00038250000000000003
