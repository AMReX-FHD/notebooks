# %%
import yt
import numpy as np
import math
import matplotlib.pyplot as plt
# Out:
# /usr/lib/python3.8/_collections_abc.py:666: MatplotlibDeprecationWarning: The global colormaps dictionary is no longer considered public API.
#   self[key]

# %%
def return_y_plt(folder,time,nbins,field="densityMean"):
    ds = yt.load(folder+time)
    ad = ds.all_data()
    plot = yt.ProfilePlot(ad,"x",[field],weight_field="cell_volume",x_log=False,y_log={field:False},n_bins=nbins)
    profile = plot.profiles[0]
    x = np.array(profile.x)
    y = np.array(profile[field])
    return x, y

# %%
time = "/pltcu0000"+"14000000/"
x1a, y1a = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="rhoMean_00")
x2a, y2a = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="rhoMean_01")

time = "/pltcu0000"+"05000000/"
x1b, y1b = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="rhoMean_00")
x2b, y2b = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="rhoMean_01")

time = "/pltprim0000"+"14000000/"
x5a, y5a = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="uMean")
x4a, y4a = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="rhoMean")
x3a, y3a = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="TMean")

time = "/pltprim0000"+"05000000/"
x5b, y5b = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="uMean")
x4b, y4b = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="rhoMean")
x3b, y3b = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="TMean")
# Out:
# yt : [INFO     ] 2022-06-09 14:13:42,315 Parameters: current_time              = 0.00041999996989215265
# yt : [INFO     ] 2022-06-09 14:13:42,316 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 14:13:42,317 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 14:13:42,318 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 14:13:42,510 Parameters: current_time              = 0.00041999996989215265
# yt : [INFO     ] 2022-06-09 14:13:42,511 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 14:13:42,511 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 14:13:42,512 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 14:13:42,711 Parameters: current_time              = 0.00014999996999523742
# yt : [INFO     ] 2022-06-09 14:13:42,712 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 14:13:42,712 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 14:13:42,713 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 14:13:42,921 Parameters: current_time              = 0.00014999996999523742
# yt : [INFO     ] 2022-06-09 14:13:42,921 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 14:13:42,922 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 14:13:42,923 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 14:13:43,105 Parameters: current_time              = 0.00041999996989215265
# yt : [INFO     ] 2022-06-09 14:13:43,105 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 14:13:43,106 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 14:13:43,107 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 14:13:43,318 Parameters: current_time              = 0.00041999996989215265
# yt : [INFO     ] 2022-06-09 14:13:43,318 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 14:13:43,319 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 14:13:43,319 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 14:13:43,500 Parameters: current_time              = 0.00041999996989215265
# yt : [INFO     ] 2022-06-09 14:13:43,501 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 14:13:43,502 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 14:13:43,502 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 14:13:43,686 Parameters: current_time              = 0.00014999996999523742
# yt : [INFO     ] 2022-06-09 14:13:43,687 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 14:13:43,687 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 14:13:43,688 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 14:13:43,886 Parameters: current_time              = 0.00014999996999523742
# yt : [INFO     ] 2022-06-09 14:13:43,887 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 14:13:43,887 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 14:13:43,888 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 14:13:44,089 Parameters: current_time              = 0.00014999996999523742
# yt : [INFO     ] 2022-06-09 14:13:44,090 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 14:13:44,091 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 14:13:44,091 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]

# %%
time = "/pltcu0000"+"20000000/"
x1a, y1a = return_y_plt('~/giganScratch/paperDSMC/KA_TG',time,nbins=128,field="rhoMean_00")
x2a, y2a = return_y_plt('~/giganScratch/paperDSMC/KA_TG',time,nbins=128,field="rhoMean_01")

time = "/pltcu0000"+"10000000/"
x1b, y1b = return_y_plt('~/giganScratch/paperDSMC/KA_TG',time,nbins=128,field="rhoMean_00")
x2b, y2b = return_y_plt('~/giganScratch/paperDSMC/KA_TG',time,nbins=128,field="rhoMean_01")

time = "/pltprim0000"+"20000000/"
x5a, y5a = return_y_plt('~/giganScratch/paperDSMC/KA_TG',time,nbins=128,field="uMean")
x4a, y4a = return_y_plt('~/giganScratch/paperDSMC/KA_TG',time,nbins=128,field="rhoMean")
x3a, y3a = return_y_plt('~/giganScratch/paperDSMC/KA_TG',time,nbins=128,field="TMean")

time = "/pltprim0000"+"10000000/"
x5b, y5b = return_y_plt('~/giganScratch/paperDSMC/KA_TG',time,nbins=128,field="uMean")
x4b, y4b = return_y_plt('~/giganScratch/paperDSMC/KA_TG',time,nbins=128,field="rhoMean")
x3b, y3b = return_y_plt('~/giganScratch/paperDSMC/KA_TG',time,nbins=128,field="TMean")
# Out:
# yt : [INFO     ] 2022-06-13 12:53:06,159 Parameters: current_time              = 0.0005999999698234295
# yt : [INFO     ] 2022-06-13 12:53:06,159 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-13 12:53:06,160 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-13 12:53:06,161 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-13 12:53:06,392 Parameters: current_time              = 0.0005999999698234295
# yt : [INFO     ] 2022-06-13 12:53:06,393 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-13 12:53:06,394 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-13 12:53:06,394 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-13 12:53:06,611 Parameters: current_time              = 0.0002999999699379681
# yt : [INFO     ] 2022-06-13 12:53:06,612 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-13 12:53:06,612 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-13 12:53:06,613 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-13 12:53:06,963 Parameters: current_time              = 0.0002999999699379681
# yt : [INFO     ] 2022-06-13 12:53:06,964 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-13 12:53:06,965 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-13 12:53:06,966 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-13 12:53:07,163 Parameters: current_time              = 0.0005999999698234295
# yt : [INFO     ] 2022-06-13 12:53:07,163 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-13 12:53:07,164 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-13 12:53:07,165 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-13 12:53:07,370 Parameters: current_time              = 0.0005999999698234295
# yt : [INFO     ] 2022-06-13 12:53:07,371 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-13 12:53:07,371 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-13 12:53:07,372 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-13 12:53:07,564 Parameters: current_time              = 0.0005999999698234295
# yt : [INFO     ] 2022-06-13 12:53:07,566 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-13 12:53:07,567 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-13 12:53:07,567 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-13 12:53:07,797 Parameters: current_time              = 0.0002999999699379681
# yt : [INFO     ] 2022-06-13 12:53:07,798 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-13 12:53:07,799 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-13 12:53:07,799 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-13 12:53:08,045 Parameters: current_time              = 0.0002999999699379681
# yt : [INFO     ] 2022-06-13 12:53:08,046 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-13 12:53:08,047 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-13 12:53:08,047 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-13 12:53:08,329 Parameters: current_time              = 0.0002999999699379681
# yt : [INFO     ] 2022-06-13 12:53:08,330 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-13 12:53:08,330 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-13 12:53:08,331 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]

# %%
time = "/pltcu0000"+"00110000/"
x1a, y1a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_00")
x2a, y2a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_01")

time = "/pltcu0000"+"00130000/"
x1b, y1b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_00")
x2b, y2b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_01")

time = "/pltprim0000"+"00110000/"
x5a, y5a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="uMean")
x4a, y4a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean")
x3a, y3a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="TMean")

time = "/pltprim0000"+"00130000/"
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="uMean")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="TMean")
# Out:
# yt : [INFO     ] 2022-05-31 11:31:30,751 Parameters: current_time              = 3.2999699999980893e-06
# yt : [INFO     ] 2022-05-31 11:31:30,752 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:31:30,753 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:31:30,754 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:31:31,048 Parameters: current_time              = 3.2999699999980893e-06
# yt : [INFO     ] 2022-05-31 11:31:31,049 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:31:31,050 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:31:31,051 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:31:31,330 Parameters: current_time              = 3.8999699999989145e-06
# yt : [INFO     ] 2022-05-31 11:31:31,330 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:31:31,331 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:31:31,332 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:31:31,622 Parameters: current_time              = 3.8999699999989145e-06
# yt : [INFO     ] 2022-05-31 11:31:31,623 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:31:31,624 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:31:31,625 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:31:31,920 Parameters: current_time              = 3.2999699999980893e-06
# yt : [INFO     ] 2022-05-31 11:31:31,921 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:31:31,922 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:31:31,923 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:31:32,241 Parameters: current_time              = 3.2999699999980893e-06
# yt : [INFO     ] 2022-05-31 11:31:32,242 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:31:32,242 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:31:32,243 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:31:32,528 Parameters: current_time              = 3.2999699999980893e-06
# yt : [INFO     ] 2022-05-31 11:31:32,529 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:31:32,530 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:31:32,531 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:31:32,891 Parameters: current_time              = 3.8999699999989145e-06
# yt : [INFO     ] 2022-05-31 11:31:32,892 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:31:32,893 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:31:32,894 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:31:33,194 Parameters: current_time              = 3.8999699999989145e-06
# yt : [INFO     ] 2022-05-31 11:31:33,195 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:31:33,196 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:31:33,197 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:31:33,475 Parameters: current_time              = 3.8999699999989145e-06
# yt : [INFO     ] 2022-05-31 11:31:33,476 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:31:33,476 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:31:33,477 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]

# %%
nc=128
LL=3.84e-04
cs=LL/nc
xDSMC=np.linspace(0.5*cs,LL-0.5*cs,nc)

# %%
filename = '/home/drladiges/Downloads/profile_neq3.txt'
data = np.loadtxt(filename, delimiter=' ', skiprows=1, dtype=str)

LL=len(data)
xFHD=[]
yFHD1=[]
yFHD2=[]
yFHD3=[]
yFHD4=[]
for i in range(LL):
    val=float(data[i,0])
    xFHD.append(val)
    val1=float(data[i,1])
    val2=float(data[i,2])
    val3=float(data[i,3])    
    rho=float(data[i,4])
    yFHD1.append(val1)
    yFHD2.append(val2)
    yFHD3.append(val3)
    yFHD4.append(rho)

# %%
LL=len(x1a)
rhoSum=[]
for i in range(LL):
    val1=y1[i]
    val2=y2[i]
    rhoSum.append(val1+val2)
    
y1rev=y1[::-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6f1e30905952> in <module>
#       2 rhoSum=[]
#       3 for i in range(LL):
# ----> 4     val1=y1[i]
#       5     val2=y2[i]
#       6     rhoSum.append(val1+val2)
#
# NameError: name 'y1' is not defined

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(xDSMC,y1a,color='red',linewidth=2, label='DSMC spec 0')
ax1.plot(xDSMC, y2a,color='blue',linewidth=2, label='DSMC spec 1')
ax1.plot(xDSMC, y1a+y2a,color='green',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y1b,color='red',linewidth=2,linestyle='dashed', label='DSMC spec 0')
ax1.plot(xDSMC,y2b,color='blue',linewidth=2,linestyle='dashed', label='DSMC spec 1')
ax1.plot(xDSMC, y1b+y2b,color='green',linewidth=2, label='DSMC total')
#ax1.plot([0,0.0004], [0.000658,0.000658],color='orange',linewidth=2)
#ax1.plot([0,0.0004], [0.001316,0.001316],color='orange',linewidth=2)
#ax1.plot(xDSMC, y2b,color='blue',linewidth=2,linestyle='dashed', label='DSMC spec 1')
#ax1.plot(xDSMC, y1b+y2b,color='green',linewidth=2,linestyle='dashed', label='DSMC total')
#ax1.plot(xFHD,yFHD1,color='red',linewidth=2,linestyle='dashed', label='FHD spec 0')
#ax1.plot(xFHD,yFHD2,color='blue',linewidth=2,linestyle='dashed', label='FHD spec 1')
#ax1.plot(xFHD,yFHD4,color='black',linewidth=2,linestyle='dashed', label='FHD total')


ax1.set_xlabel(r'$x$', fontsize=30)
ax1.set_ylabel(r"$\rho$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.6),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


ax2 = fig.add_subplot(1,2,2)


#ax2.plot(xDSMC,y3a,color='purple',linewidth=2, label='DSMC')
ax2.plot(xDSMC,y3a,color='purple',linewidth=2, label='DSMC')
ax2.plot(xDSMC,y3b,color='purple',linewidth=2, label='DSMC',linestyle='dashed')
#ax2.plot(xDSMC,y3b,color='green',linewidth=2, label='2')
#ax2.plot(xDSMC,y3c,color='orange',linewidth=2, label='2 million development')
#ax2.plot(xFHD,yFHD3,color='black',linewidth=2,linestyle='dashed', label='FHD')

ax2.set_xlabel(r'$x$', fontsize=30)
ax2.set_ylabel(r"$T$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.53,0.6),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("profiles.pdf", bbox_inches = 'tight', pad_inches = 0.05)

# %%
y3a[0]
# Out:
# 269.8008869619002

# %%
sum(yFHD4)
# Out:
# 0.08425534557969508

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

#ax1.plot(xDSMC,y1,color='red',linewidth=2, label='DSMC spec 1')
#ax1.plot(xDSMC,y2,color='blue',linewidth=2, label='DSMC spec 2')
#ax1.plot(xDSMC,y5a,color='green',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y5b,color='purple',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y5a,color='purple',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y5b,color='green',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y5c,color='orange',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y5c,color='blue',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y4b,color='purple',linewidth=2, label='DSMC total')
#ax1.plot(xFHD,yFHD4,color='red',linewidth=2,linestyle='dashed', label='FHD spec 1')
#ax1.plot(xDSMC,rhoSum,color='blue',linewidth=2,linestyle='dashed', label='DSMC sum')


ax1.set_xlabel(r'$x$', fontsize=30)
ax1.set_ylabel(r"$u$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.6),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


#ax2 = fig.add_subplot(1,2,2)

#ax2.plot(xDSMC,y3a,color='red',linewidth=2, label='DSMC')
#ax2.plot(xDSMC,y3b,color='black',linewidth=2, label='DSMC')
#ax2.plot(xDSMC,y3c,color='black',linewidth=2, label='DSMC')
#ax2.plot(xFHD,yFHD3,color='black',linewidth=2,linestyle='dashed', label='FHD')


#ax2.set_xlabel(r'$x$', fontsize=30)
#ax2.set_ylabel(r"$T$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
#ax2.tick_params(labelsize=20)
#ax2.legend(loc=(0.53,0.6),fontsize=20)
#ax2.xaxis.set_tick_params(width=1.5)
#ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("vel.pdf", bbox_inches = 'tight', pad_inches = 0.05)

# %%
filename = '/home/drladiges/Downloads/correl_neq1.txt'
data = np.loadtxt(filename, delimiter=' ', skiprows=1, dtype=str)



LL=len(data)
xFHDb=[]
yFHD1b=[]
yFHD2b=[]
yFHD3b=[]
for i in range(LL):
    val=float(data[i,0])
    xFHDb.append(val)
    #fhdcell=(xFHDb[1]-xFHDb[0])**3;
    #dsmccell=(3.84e-04/128)*((0.035e-4)**2);
    #cellRat=fhdcell/dsmccell
    
    val1=float(data[i,4])*cellRat
    val2=float(data[i,5])*cellRat
    val3=float(data[i,6])*cellRat
    yFHD1b.append(val1)
    yFHD2b.append(val2)
    yFHD3b.append(val3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-f36bdcb10738> in <module>
#      16     #cellRat=fhdcell/dsmccell
#      17
# ---> 18     val1=float(data[i,4])*cellRat
#      19     val2=float(data[i,5])*cellRat
#      20     val3=float(data[i,6])*cellRat
#
# NameError: name 'cellRat' is not defined

# %%
time = "/pltvar0000"+"00060000/"
x1b, y1b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho0*.rho0")
x2b, y2b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho1*.rho1")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho1*.rho0")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="T*.T")
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho*.rho")
x6b, y6b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoVar")
# Out:
# yt : [INFO     ] 2022-05-31 11:32:38,236 Parameters: current_time              = 1.7999699999990352e-06
# yt : [INFO     ] 2022-05-31 11:32:38,237 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:32:38,238 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:32:38,239 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:32:38,553 Parameters: current_time              = 1.7999699999990352e-06
# yt : [INFO     ] 2022-05-31 11:32:38,553 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:32:38,554 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:32:38,555 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:32:38,909 Parameters: current_time              = 1.7999699999990352e-06
# yt : [INFO     ] 2022-05-31 11:32:38,910 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:32:38,911 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:32:38,912 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:32:39,217 Parameters: current_time              = 1.7999699999990352e-06
# yt : [INFO     ] 2022-05-31 11:32:39,218 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:32:39,218 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:32:39,219 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:32:39,514 Parameters: current_time              = 1.7999699999990352e-06
# yt : [INFO     ] 2022-05-31 11:32:39,515 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:32:39,516 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:32:39,517 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-31 11:32:39,805 Parameters: current_time              = 1.7999699999990352e-06
# yt : [INFO     ] 2022-05-31 11:32:39,806 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-31 11:32:39,807 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-31 11:32:39,807 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]

# %%
time = "/pltvar0000"+"14000000/"
x1b, y1b = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="u*.rho")
x2b, y2b = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="T*.rho")
x3b, y3b = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="T*.T")
x4b, y4b = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="TVar")
x5b, y5b = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="rhoVar")
x6b, y6b = return_y_plt('~/giganScratch/paperDSMC/RB_TG',time,nbins=128,field="rhoVar")
# Out:
# yt : [INFO     ] 2022-06-09 13:39:06,259 Parameters: current_time              = 0.00041999996989215265
# yt : [INFO     ] 2022-06-09 13:39:06,260 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 13:39:06,261 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 13:39:06,263 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 13:39:06,713 Parameters: current_time              = 0.00041999996989215265
# yt : [INFO     ] 2022-06-09 13:39:06,714 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 13:39:06,715 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 13:39:06,715 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 13:39:06,921 Parameters: current_time              = 0.00041999996989215265
# yt : [INFO     ] 2022-06-09 13:39:06,922 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 13:39:06,923 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 13:39:06,924 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 13:39:07,134 Parameters: current_time              = 0.00041999996989215265
# yt : [INFO     ] 2022-06-09 13:39:07,134 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 13:39:07,135 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 13:39:07,135 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 13:39:07,344 Parameters: current_time              = 0.00041999996989215265
# yt : [INFO     ] 2022-06-09 13:39:07,345 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 13:39:07,345 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 13:39:07,346 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-06-09 13:39:07,549 Parameters: current_time              = 0.00041999996989215265
# yt : [INFO     ] 2022-06-09 13:39:07,550 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-06-09 13:39:07,551 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-09 13:39:07,553 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,21])
plt.subplots_adjust(wspace=0.25)


ax1 = fig.add_subplot(2,2,1)

ax1.plot(xDSMC,dsmccell*y1b/np.sqrt(2),color='black',linewidth=2, label='DSMC')
#ax1.plot(xFHDb,yFHD1b,color='black',linewidth=2,linestyle='dashed', label='FHD')



ax1.set_xlabel(r'$x$', fontsize=20)
ax1.set_ylabel(r"$<\delta u^*\delta \rho>$", fontsize=30,rotation=90, labelpad=10)
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.7,0.8),fontsize=20)
#ax1.set_ylim([-100e-21,50e-21])
ax1.set_ylim([-10e-21,5e-21])
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)



ax2 = fig.add_subplot(2,2,2)

ax2.plot(xDSMC,dsmccell*y2b,color='black',linewidth=2, label='DSMC')
#ax2.plot(xFHDb,yFHD3b,color='black',linewidth=2,linestyle='dashed', label='FHD')

ax2.set_xlabel(r'$x$', fontsize=30)
ax2.set_ylabel(r"$<\delta T^*\delta \rho>$", fontsize=30,rotation=90, labelpad=10)
#ax2.set_ylabel(r"$<\delta T^*\delta T>$", fontsize=30,rotation=90, labelpad=10)
ax2.set_ylim([-2e-22,3e-22])
#ax1.set_xlim([-0.1e-7,2e-7])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.7,0.2),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("correlations.pdf", bbox_inches = 'tight', pad_inches = 0.05)

ax3 = fig.add_subplot(2,2,3)
ax3.plot(xDSMC,dsmccell*y3b,color='black',linewidth=2, label='DSMC')

ax3.set_xlabel(r'$x$', fontsize=30)
ax3.set_ylabel(r"$<\delta T^* \delta T >$", fontsize=30,rotation=90, labelpad=10)
ax3.set_ylim([-2e-18,15e-18])
ax3.tick_params(labelsize=20)
ax3.legend(loc=(0.7,0.2),fontsize=20)
ax3.xaxis.set_tick_params(width=1.5)
ax3.yaxis.set_tick_params(width=1.5)

ax4 = fig.add_subplot(2,2,4)
ax4.plot(xDSMC,dsmccell*y4b,color='black',linewidth=2, label='DSMC')

ax4.set_xlabel(r'$x$', fontsize=30)
ax4.set_ylabel(r"$<\delta T \delta T>$", fontsize=30,rotation=90, labelpad=10)
ax4.set_ylim([0,1.5e-14])
ax4.tick_params(labelsize=20)
ax4.legend(loc=(0.7,0.2),fontsize=20)
ax4.xaxis.set_tick_params(width=1.5)
ax4.yaxis.set_tick_params(width=1.5)

# %%
dsmccell*y3b
# Out:
# array([ 6.24872721e-19,  8.54174430e-19,  1.72724380e-18,  2.40006989e-18,
#         2.67123934e-18,  1.76474015e-18,  3.21382606e-18,  3.31801688e-18,
#         2.39218209e-18,  4.77738116e-18,  4.52659749e-18,  4.03084765e-18,
#         3.99172005e-18,  5.68316246e-18,  5.05862621e-18,  6.31687790e-18,
#         4.88160786e-18,  6.59032016e-18,  6.96451447e-18,  5.62443635e-18,
#         6.40522933e-18,  6.25894946e-18,  6.06882833e-18,  8.96768645e-18,
#         8.94209652e-18,  9.88723857e-18,  1.05709802e-17,  7.49593982e-18,
#         9.23040401e-18,  1.06132872e-17,  8.51519411e-18,  9.26422132e-18,
#         2.63377689e-15,  9.04473966e-18,  7.80404571e-18,  7.93414891e-18,
#         7.70913795e-18,  6.04388437e-18,  7.31971457e-18,  7.37631194e-18,
#         6.71855654e-18,  7.81083720e-18,  6.75563327e-18,  6.92499090e-18,
#         7.63601912e-18,  6.76990264e-18,  7.22375725e-18,  8.55486673e-18,
#         5.54794091e-18,  7.58652704e-18,  8.14624708e-18,  7.70952651e-18,
#         5.92365738e-18,  4.43835827e-18,  6.32668111e-18,  5.07324412e-18,
#         6.14023216e-18,  4.72625554e-18,  2.83602006e-18,  1.32125253e-18,
#         4.53104201e-18,  3.80282483e-18,  3.33959587e-18,  6.03440202e-18,
#         7.02854105e-18,  7.36471340e-18,  5.12896939e-18,  2.80394939e-18,
#         3.12338985e-18,  7.45729563e-18,  4.66290036e-18,  4.23739734e-18,
#         7.74319309e-18,  5.59228880e-18,  2.98500765e-18,  3.89398867e-18,
#         6.62719000e-18,  3.83794417e-18,  5.01905795e-18,  6.98846365e-18,
#         5.10057674e-18,  5.04073626e-18,  4.09610189e-18,  2.32053956e-18,
#         5.02482926e-18,  5.20098523e-18,  6.49547740e-18,  3.28618390e-18,
#        -1.33157666e-19,  1.25371570e-18,  3.99063427e-18,  3.14592721e-18,
#         1.73349745e-18,  1.54350453e-18,  3.82520787e-18,  3.00413391e-18,
#         1.80358995e-18,  4.07516886e-18,  4.43095897e-18,  1.60200290e-19,
#         2.18224072e-18,  3.00568357e-18,  2.91901067e-18,  2.97878322e-18,
#         5.80038777e-18,  1.91051519e-18,  2.47021424e-18,  4.74525391e-18,
#         9.29593685e-19,  3.77725335e-18,  5.08018275e-18,  6.96847586e-18,
#         4.39088011e-18,  3.89520230e-18,  7.32529662e-18,  5.09775392e-18,
#         3.83165184e-18,  4.22516989e-18,  3.48358488e-18,  1.75350919e-18,
#         3.21519432e-18,  2.30674657e-18,  2.70926788e-18,  5.06828937e-18,
#         2.95809804e-18,  4.81092920e-19,  1.47429611e-18,  1.53140325e-18])

# %%
fhdcell=(xFHD[1]-xFHD[0])**3;
dsmccell=(3.84e-04/128)*((0.035e-4)*(0.035e-4));
cellRat=fhdcell/dsmccell
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-94be7cce0319> in <module>
# ----> 1 fhdcell=(xFHD[1]-xFHD[0])**3;
#       2 dsmccell=(3.84e-04/128)*((0.035e-4)*(0.035e-4));
#       3 cellRat=fhdcell/dsmccell
#
# NameError: name 'xFHD' is not defined

# %%
y4b
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
dsmccell
# Out:
# 3.675e-17

# %%
fhdcell
# Out:
# 2.2644984342943527e-16

# %%
fhdc=xFHD[2]-xFHD[1]

# %%
dsmcc=xDSMC[2]-xDSMC[1]

# %%
xFHD[0]
# Out:
# 3e-06

# %%
xDSMC[1]-dsmcc/2
# Out:
# 3.000000000000001e-06

# %%
xFHD[0]
# Out:
# 3e-06

# %%
xDSMC[127]
# Out:
# 0.00038250000000000003
