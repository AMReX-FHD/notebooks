# %%
import yt
import numpy as np
import math
import matplotlib.pyplot as plt
# Out:
# /usr/lib/python3.8/_collections_abc.py:666: MatplotlibDeprecationWarning: The global colormaps dictionary is no longer considered public API.
#   self[key]

# %%
def return_y_plt(folder,time,nbins,field="densityMean"):
    ds = yt.load(folder+time)
    ad = ds.all_data()
    plot = yt.ProfilePlot(ad,"x",[field],weight_field="cell_volume",x_log=False,y_log={field:False},n_bins=nbins)
    profile = plot.profiles[0]
    x = np.array(profile.x)
    y = np.array(profile[field])
    return x, y

# %%
time = "/pltcu0000"+"02000000/"
x1a, y1a = return_y_plt('~/giganScratch/DSMCtest1',time,nbins=128,field="rhoMean_00")
x2a, y2a = return_y_plt('~/giganScratch/DSMCtest1',time,nbins=128,field="rhoMean_01")

time = "/pltcu0000"+"02000000/"
x1b, y1b = return_y_plt('~/giganScratch/DSMCtest1',time,nbins=128,field="rhoMean_00")
x2b, y2b = return_y_plt('~/giganScratch/DSMCtest1',time,nbins=128,field="rhoMean_01")

time = "/pltprim0000"+"02000000/"
x5a, y5a = return_y_plt('~/giganScratch/DSMCtest1',time,nbins=128,field="uMean")
x4a, y4a = return_y_plt('~/giganScratch/DSMCtest1',time,nbins=128,field="rhoMean")
x3a, y3a = return_y_plt('~/giganScratch/DSMCtest1',time,nbins=128,field="TMean")

time = "/pltprim0000"+"02000000/"
x5b, y5b = return_y_plt('~/giganScratch/DSMCtest1',time,nbins=128,field="uMean")
x4b, y4b = return_y_plt('~/giganScratch/DSMCtest1',time,nbins=128,field="rhoMean")
x3b, y3b = return_y_plt('~/giganScratch/DSMCtest1',time,nbins=128,field="TMean")
# Out:
# yt : [INFO     ] 2022-05-11 00:54:54,287 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-11 00:54:54,288 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:54:54,290 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:54:54,291 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-11 00:54:55,517 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-11 00:54:55,518 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:54:55,520 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:54:55,521 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-11 00:54:56,704 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-11 00:54:56,705 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:54:56,706 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:54:56,707 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-11 00:54:57,893 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-11 00:54:57,895 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:54:57,896 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:54:57,898 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-11 00:54:59,186 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-11 00:54:59,186 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:54:59,187 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:54:59,188 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-11 00:55:01,483 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-11 00:55:01,485 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:55:01,486 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:55:01,487 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-11 00:55:02,676 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-11 00:55:02,677 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:55:02,678 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:55:02,679 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-11 00:55:03,868 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-11 00:55:03,869 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:55:03,871 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:55:03,872 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-11 00:55:05,503 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-11 00:55:05,505 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:55:05,506 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:55:05,507 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]
# yt : [INFO     ] 2022-05-11 00:55:06,696 Parameters: current_time              = 5.9999970001558696e-05
# yt : [INFO     ] 2022-05-11 00:55:06,697 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:55:06,698 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:55:06,699 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 3.50e-06]

# %%
time = "/pltcu0000"+"00030000/"
x1a, y1a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_00")
x2a, y2a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_01")

time = "/pltcu0000"+"00020000/"
x1b, y1b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_00")
x2b, y2b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean_01")

time = "/pltprim0000"+"00030000/"
x5a, y5a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="uMean")
x4a, y4a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean")
x3a, y3a = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="TMean")

time = "/pltprim0000"+"00020000/"
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="uMean")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rhoMean")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="TMean")
# Out:
# yt : [INFO     ] 2022-05-11 00:11:51,712 Parameters: current_time              = 8.999699999996027e-07
# yt : [INFO     ] 2022-05-11 00:11:51,713 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:11:51,715 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:11:51,716 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-11 00:11:53,874 Parameters: current_time              = 8.999699999996027e-07
# yt : [INFO     ] 2022-05-11 00:11:53,875 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:11:53,876 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:11:53,877 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-11 00:11:55,182 Parameters: current_time              = 5.999699999997919e-07
# yt : [INFO     ] 2022-05-11 00:11:55,183 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:11:55,185 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:11:55,186 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-11 00:11:57,301 Parameters: current_time              = 5.999699999997919e-07
# yt : [INFO     ] 2022-05-11 00:11:57,302 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:11:57,304 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:11:57,305 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-11 00:11:58,967 Parameters: current_time              = 8.999699999996027e-07
# yt : [INFO     ] 2022-05-11 00:11:58,969 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:11:58,970 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:11:58,970 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-11 00:12:01,352 Parameters: current_time              = 8.999699999996027e-07
# yt : [INFO     ] 2022-05-11 00:12:01,353 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:12:01,355 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:12:01,357 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-11 00:12:02,527 Parameters: current_time              = 8.999699999996027e-07
# yt : [INFO     ] 2022-05-11 00:12:02,528 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:12:02,529 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:12:02,531 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-11 00:12:03,823 Parameters: current_time              = 5.999699999997919e-07
# yt : [INFO     ] 2022-05-11 00:12:03,825 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:12:03,826 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:12:03,828 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-11 00:12:05,998 Parameters: current_time              = 5.999699999997919e-07
# yt : [INFO     ] 2022-05-11 00:12:05,999 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:12:06,002 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:12:06,003 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-11 00:12:07,187 Parameters: current_time              = 5.999699999997919e-07
# yt : [INFO     ] 2022-05-11 00:12:07,188 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-11 00:12:07,190 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-11 00:12:07,191 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]

# %%
nc=128
LL=3.84e-04
cs=LL/nc
xDSMC=np.linspace(0.5*cs,LL-0.5*cs,nc)

# %%
filename = '/home/drladiges/Downloads/profile_neq1.txt'
data = np.loadtxt(filename, delimiter=' ', skiprows=1, dtype=str)

LL=len(data)
xFHD=[]
yFHD1=[]
yFHD2=[]
yFHD3=[]
yFHD4=[]
for i in range(LL):
    val=float(data[i,0])
    xFHD.append(val)
    val1=float(data[i,7])
    val2=float(data[i,8])
    val3=float(data[i,5])    
    rho=float(data[i,1])
    yFHD1.append(val1*rho)
    yFHD2.append(val2*rho)
    yFHD3.append(val3)
    yFHD4.append(rho)

# %%
LL=len(x1)
rhoSum=[]
for i in range(LL):
    val1=y1[i]
    val2=y2[i]
    rhoSum.append(val1+val2)
    
y1rev=y1[::-1]

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(xDSMC,y1a,color='red',linewidth=2, label='DSMC spec 0')
ax1.plot(xDSMC, y2a,color='blue',linewidth=2, label='DSMC spec 1')
ax1.plot(xDSMC, y1a+y2a,color='green',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y1b,color='red',linewidth=2,linestyle='dashed', label='DSMC spec 0')
ax1.plot(xDSMC, y2b,color='blue',linewidth=2,linestyle='dashed', label='DSMC spec 1')
ax1.plot(xDSMC, y1b+y2b,color='green',linewidth=2,linestyle='dashed', label='DSMC total')
#ax1.plot(xFHD,yFHD1,color='black',linewidth=2,linestyle='dashed', label='FHD spec 1')
#ax1.plot(xFHD,yFHD2,color='black',linewidth=2,linestyle='dashed', label='FHD spec 2')


ax1.set_xlabel(r'$x$', fontsize=30)
ax1.set_ylabel(r"$\rho$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.6),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


ax2 = fig.add_subplot(1,2,2)


#ax2.plot(xDSMC,y3a,color='purple',linewidth=2, label='DSMC')
ax2.plot(xDSMC,y3a,color='purple',linewidth=2, label='1')
#ax2.plot(xDSMC,y3b,color='green',linewidth=2, label='2')
#ax2.plot(xDSMC,y3c,color='orange',linewidth=2, label='2 million development')
#ax2.plot(xFHD,yFHD3,color='black',linewidth=2,linestyle='dashed', label='FHD')

ax2.set_xlabel(r'$x$', fontsize=30)
ax2.set_ylabel(r"$T$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.53,0.6),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("profiles.pdf", bbox_inches = 'tight', pad_inches = 0.05)

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.20)


ax1 = fig.add_subplot(1,2,1)

#ax1.plot(xDSMC,y1,color='red',linewidth=2, label='DSMC spec 1')
#ax1.plot(xDSMC,y2,color='blue',linewidth=2, label='DSMC spec 2')
#ax1.plot(xDSMC,y5a,color='green',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y5b,color='purple',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y5a,color='purple',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y5b,color='green',linewidth=2, label='DSMC total')
ax1.plot(xDSMC,y5c,color='orange',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y5c,color='blue',linewidth=2, label='DSMC total')
#ax1.plot(xDSMC,y4b,color='purple',linewidth=2, label='DSMC total')
#ax1.plot(xFHD,yFHD4,color='red',linewidth=2,linestyle='dashed', label='FHD spec 1')
#ax1.plot(xDSMC,rhoSum,color='blue',linewidth=2,linestyle='dashed', label='DSMC sum')


ax1.set_xlabel(r'$x$', fontsize=30)
ax1.set_ylabel(r"$u$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.53,0.6),fontsize=20)
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


#ax2 = fig.add_subplot(1,2,2)

#ax2.plot(xDSMC,y3a,color='red',linewidth=2, label='DSMC')
#ax2.plot(xDSMC,y3b,color='black',linewidth=2, label='DSMC')
#ax2.plot(xDSMC,y3c,color='black',linewidth=2, label='DSMC')
#ax2.plot(xFHD,yFHD3,color='black',linewidth=2,linestyle='dashed', label='FHD')


#ax2.set_xlabel(r'$x$', fontsize=30)
#ax2.set_ylabel(r"$T$", fontsize=30,rotation=0, labelpad=15)
#ax1.set_ylim([-20,1444])
#ax1.set_xlim([-0.1e-7,2e-7])
#ax2.tick_params(labelsize=20)
#ax2.legend(loc=(0.53,0.6),fontsize=20)
#ax2.xaxis.set_tick_params(width=1.5)
#ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("vel.pdf", bbox_inches = 'tight', pad_inches = 0.05)

# %%
filename = '/home/drladiges/Downloads/correl_neq1.txt'
data = np.loadtxt(filename, delimiter=' ', skiprows=1, dtype=str)



LL=len(data)
xFHDb=[]
yFHD1b=[]
yFHD2b=[]
yFHD3b=[]
for i in range(LL):
    val=float(data[i,0])
    xFHDb.append(val)
    fhdcell=(xFHDb[1]-xFHDb[0])**3;
    dsmccell=(3.84e-04/128)*((0.035e-4)**2);
    cellRat=fhdcell/dsmccell
    
    val1=float(data[i,4])*cellRat
    val2=float(data[i,5])*cellRat
    val3=float(data[i,6])*cellRat
    yFHD1b.append(val1)
    yFHD2b.append(val2)
    yFHD3b.append(val3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-e367de527887> in <module>
#      12     val=float(data[i,0])
#      13     xFHDb.append(val)
# ---> 14     fhdcell=(xFHDb[1]-xFHDb[0])**3;
#      15     dsmccell=(3.84e-04/128)*((0.035e-4)**2);
#      16     cellRat=fhdcell/dsmccell
#
# IndexError: list index out of range

# %%
time = "/pltvar0000"+"00010000/"
x1b, y1b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho0*.rho0")
x2b, y2b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho1*.rho1")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho1*.rho0")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="T*.T")
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho*.rho")
# Out:
# yt : [INFO     ] 2022-05-10 19:45:54,926 Parameters: current_time              = 2.999699999999811e-07
# yt : [INFO     ] 2022-05-10 19:45:54,927 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-10 19:45:54,928 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-10 19:45:54,930 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-10 19:45:58,458 Parameters: current_time              = 2.999699999999811e-07
# yt : [INFO     ] 2022-05-10 19:45:58,459 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-10 19:45:58,460 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-10 19:45:58,462 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-10 19:46:00,135 Parameters: current_time              = 2.999699999999811e-07
# yt : [INFO     ] 2022-05-10 19:46:00,136 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-10 19:46:00,137 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-10 19:46:00,138 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-10 19:46:01,797 Parameters: current_time              = 2.999699999999811e-07
# yt : [INFO     ] 2022-05-10 19:46:01,798 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-10 19:46:01,799 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-10 19:46:01,801 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]
# yt : [INFO     ] 2022-05-10 19:46:03,491 Parameters: current_time              = 2.999699999999811e-07
# yt : [INFO     ] 2022-05-10 19:46:03,493 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2022-05-10 19:46:03,494 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-10 19:46:03,495 Parameters: domain_right_edge         = [3.84e-04 3.50e-06 7.00e-06]

# %%
time = "/pltvar0000"+"00010000/"
x1b, y1b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho0*.rho0")
x2b, y2b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho1*.rho1")
x3b, y3b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho1*.rho0")
x4b, y4b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="T*.T")
x5b, y5b = return_y_plt('~/gigan/projects/FHDeX/exec/DSMC',time,nbins=128,field="rho*.rho")

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 
plt.rc('axes', linewidth=1.5)
fig = plt.figure(figsize=[21,10])
plt.subplots_adjust(wspace=0.25)


ax1 = fig.add_subplot(1,2,1)

ax1.plot(xDSMC,y1b/5.8,color='black',linewidth=2, label='DSMC')
#ax1.plot(xFHDb,yFHD1b,color='black',linewidth=2,linestyle='dashed', label='FHD')



ax1.set_xlabel(r'$x$', fontsize=20)
ax1.set_ylabel(r"$<\delta \rho_0^*\delta \rho_0>$", fontsize=30,rotation=90, labelpad=10)
ax1.tick_params(labelsize=20)
ax1.legend(loc=(0.7,0.8),fontsize=20)
ax1.set_ylim([-55e-14,1e-14])
ax1.xaxis.set_tick_params(width=1.5)
ax1.yaxis.set_tick_params(width=1.5)


#ax2 = fig.add_subplot(1,2,2)

#ax2.plot(xDSMC,y2b,color='black',linewidth=2, label='DSMC')
#ax2.plot(xFHDb,yFHD2b,color='black',linewidth=2,linestyle='dashed', label='FHD')

#ax2.set_xlabel(r'$x$', fontsize=30)
#ax2.set_ylabel(r"$<\delta \rho_1^*\delta \rho_1>$", fontsize=30,rotation=90, labelpad=10)
#ax2.set_ylim([-100e-13,100e-13])
#ax1.set_xlim([-0.1e-7,2e-7])
#ax2.tick_params(labelsize=20)
#ax2.legend(loc=(0.7,0.8),fontsize=20)
#ax2.xaxis.set_tick_params(width=1.5)
#ax2.yaxis.set_tick_params(width=1.5)


ax2 = fig.add_subplot(1,2,2)

ax2.plot(xDSMC,y3b/5.8,color='black',linewidth=2, label='DSMC')
#ax2.plot(xFHDb,yFHD3b,color='black',linewidth=2,linestyle='dashed', label='FHD')

ax2.set_xlabel(r'$x$', fontsize=30)
ax2.set_ylabel(r"$<\delta \rho_1^*\delta \rho_0>$", fontsize=30,rotation=90, labelpad=10)
ax2.set_ylim([-5e-13,5e-13])
#ax1.set_xlim([-0.1e-7,2e-7])
ax2.tick_params(labelsize=20)
ax2.legend(loc=(0.7,0.2),fontsize=20)
ax2.xaxis.set_tick_params(width=1.5)
ax2.yaxis.set_tick_params(width=1.5)

fig.savefig("correlations.pdf", bbox_inches = 'tight', pad_inches = 0.05)

# %%
fhdcell=(xFHD[1]-xFHD[0])**3;
dsmccell=(3.84e-04/128)*((0.035e-4)**2);
cellRat=fhdcell/dsmccell

# %%
cellRat
# Out:
# 6.161900501481232

# %%
dsmccell
# Out:
# 3.675e-17
